# %% [markdown]
# # Music Through the Decades
#
# ### Intro
# As I'm typing this introduction, I'm bopping to "Holiday" by Green Day, on a random "Pump Up Music" playlist that I found 5 minutes ago (thank you apache_king!). Music has played and continues to play a very important part of my life. I've been jamming to something or the other since first grade, learned to play the guitar in second grade, and have been in every band I possibly could throughout elementary, middle, and high school. Ever since starting college, I've gone to over 10 different concerts, and much to my roommates' consternation, every time I shower I blare anything from Imagine Dragons to Logic to Linkin Park to Queen (and badly sing to it).
#
# Needless to say, music is important to me. It's how I process my emotions when I'm upset, motivate myself when I feel lazy, and run the extra 3 minutes (because running the extra mile is too much to ask for) when I'm sweating it out at the gym. I'm sure I'm not the only one like this either. The emotions of a generation are forever captured by the popularity of songs of that time. Music has come to define eras and decades, like the psychedlic rock of the Beatles dominating the 60s, the eccentric theatric rock of Queen of the 80s, and even artists like NSYNC coming to embody the odd time that was the 90s.
#
# ### Goals of the Project
# We thought it would be interesting to see if there were changes between the popular music of the decades from the 50s through the 2010s. With every generation facing a different landscape, from the post-war economic boom in the 50s to recession in the late 2000s, we thought it would be interesting to explore whether changes in music reflected that. Would the uncertainty of a war with Russia in the 80s drive people to seek out more angry or sad music? Would the happiness after the end of World War 2 be reflected in the popularity of the songs in that era? By that token, by analyzing the popular songs of these decades, can we build a classifier that could predict the era a song was created in based off of its audio features?
#
# ### How We Will Do This
# Using Spotify and Genius's Web APIs, we wanted to explore these questions and present a case study in the changes in popular music over the decades. We will use Spotify's own "All Out" playlists, which are organized by decade. We felt that these playlists would prove a promising source of information about the popular songs of a certain decade. We will use Spotify's API to be able to gain information about the features of the track, from danceability to 'speechiness'.

# %% [markdown]
# ## Step One : Imports
# The first thing we did was import everything that we needed. Because we were accessing the Spotify and Genius APIs, we use the requests library as well as others to be able to parse the information we query into a dataframe. We will also later use the Natural Language ToolKit (or NLTK) to meaningfully analyze text, so we download the necessary modules from within that as well. Lastly, for preliminary machine learning, we also imported different modules within SciKit-Learn.

# %%
# Request / Parsing 
import requests
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from pandas.io.json import json_normalize
import string

#Visualization and EDA 
import sys 
# The below 3 statements were only done because we were coding within a Jupyter notebook set up for our class (CMSC320). 
# For those following at home, you will likely just need to pip install these in your command-line, instead of within 
# the confines of the notebook itself. 

# !{sys.executable} -m pip install Pillow  
# !{sys.executable} -m pip install wordcloud
# !{sys.executable} -m pip install -U nltk
import matplotlib.pyplot as plt
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('punkt')
nltk.download('stopwords')

#Machine Learning 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.externals import joblib

# %% [markdown]
# ## STEP 2: Gaining Access to the Spotify and Genius Web APIs
# To be able to continue with this project, you need authentification tokens provided through Spotify. We would periodically request tokens from this website : https://developer.spotify.com/console/get-playlist-tracks/?playlist_id=37i9dQZF1DX5Ejj0EkURtP&market=&fields=&limit=&offset= to query Spotify. This requires a Spotify account. Similarly, Genius's API requires an account as well. We used this website: https://docs.genius.com/#/getting-started-h1 to set up our own accounts.
#
# Afterwards, store the tokens within variables.

# %%
# https://developer.spotify.com/console/get-playlist-tracks/?playlist_id=37i9dQZF1DX5Ejj0EkURtP&market=&fields=&limit=&offset= 
# use above website to generate token
token = "BQCPIyhj4-vpryQ7Pd9fIa5SiK864LOOLxGrCRqc1Kp2cYsk9kn6aUchjuUQBHVlwlHRqkwrFN-6zAVB4QHCQIg7MX4pvGG0ls3Aj02Jd0Eb8dGGeSgmba3YrfTIl00pYsvnb8zfzhuYsZa_Zg"
# https://genius.com/api-clients ==> use this website to generate token
genius_token = 'V3BxSvKtWKcSlonUDfqeKWZmRKK3qjGyAGJCRqxm8awvuWI65nm7WFrYmnn3acIu'

# token = "INSERT SPOTIFY TOKEN HERE"
# genius_token = "INSERT GENIUS TOKEN HERE"

# %% [markdown]
# ## STEP 3: Getting the Information Into a Dataframe

# %%
#playlist_ids = ["37i9dQZF1DX5Ejj0EkURtP", "37i9dQZF1DX4o1oenSJRJd","37i9dQZF1DXbTxeAdrVG2l", "37i9dQZF1DX4UtSsGT1Sbe", "37i9dQZF1DWTJ7xPn4vNaz", "37i9dQZF1DXaKIA8E7WcJj", "37i9dQZF1DWSV3Tk4GO2fq"] ]

r_10s = requests.get("https://api.spotify.com/v1/playlists/37i9dQZF1DX5Ejj0EkURtP", headers={'Authorization': 'Bearer ' + token})
r_00s = requests.get("https://api.spotify.com/v1/playlists/37i9dQZF1DX4o1oenSJRJd", headers={'Authorization': 'Bearer ' + token})
r_90s = requests.get("https://api.spotify.com/v1/playlists/37i9dQZF1DXbTxeAdrVG2l", headers={'Authorization': 'Bearer ' + token})
r_80s = requests.get("https://api.spotify.com/v1/playlists/37i9dQZF1DX4UtSsGT1Sbe", headers={'Authorization': 'Bearer ' + token})
r_70s = requests.get("https://api.spotify.com/v1/playlists/37i9dQZF1DWTJ7xPn4vNaz", headers={'Authorization': 'Bearer ' + token})
r_60s = requests.get("https://api.spotify.com/v1/playlists/37i9dQZF1DXaKIA8E7WcJj", headers={'Authorization': 'Bearer ' + token})
r_50s = requests.get("https://api.spotify.com/v1/playlists/37i9dQZF1DWSV3Tk4GO2fq", headers={'Authorization': 'Bearer ' + token})

# %%
json_data = r_10s.json()
playlists_10 = json_normalize(json_data["tracks"]["items"], [['track', 'artists']], ['added_at', ['track', 'popularity'], ['track', 'id'], ['track', 'name'], ['track', 'duration_ms']], errors='ignore')
playlists_10 = playlists_10.drop(columns=['external_urls', 'href', 'type', 'uri'])

playlists_10
# Out:
#                          id                  name              added_at  \
# 0    4UXqAaa6dQYAk18Lv7PEgX          Fall Out Boy  2018-12-01T17:58:03Z
# 1    3NPpFNZtSTHheNBaWC82rB         X Ambassadors  2018-12-01T17:58:03Z
# 2    10exVja0key0uqUkk6LJRT             Vance Joy  2018-12-01T17:58:03Z
# 3    4BxCuXFJrSWGi1KHcVqaU4              Kodaline  2018-12-01T17:58:03Z
# 4    246dkjvS1zLTtiykXe5h60           Post Malone  2018-12-01T17:58:03Z
# 5    536BYVgOnRky0xjsPT96zl  Two Door Cinema Club  2018-12-01T17:58:03Z
# 6    2WzaAvm2bBCf4pEhyuDgCY               Ruth B.  2018-12-01T17:58:03Z
# 7    10exVja0key0uqUkk6LJRT             Vance Joy  2018-12-01T17:58:03Z
# 8    4BxCuXFJrSWGi1KHcVqaU4              Kodaline  2018-12-01T17:58:03Z
# 9    58MLl9nC29IXbE4nEtuoP2         Alex & Sierra  2018-12-01T17:58:03Z
# 10   7Ln80lUS6He07XvHI8qqHH        Arctic Monkeys  2018-12-01T17:58:03Z
# 11   36jaGQtMj5UWD0eO1fCVdD            Joel Adams  2018-12-01T17:58:03Z
# 12   10exVja0key0uqUkk6LJRT             Vance Joy  2018-12-01T17:58:03Z
# 13   69GGBxA162lTqCwzJG5jLp      The Chainsmokers  2018-12-01T17:58:03Z
# 14   6jTnHxhb6cDCaCu4rdvsQ0        Hot Chelle Rae  2018-12-01T17:58:03Z
# 15   0B3N0ZINFWvizfa8bKiz4v              James TW  2018-12-01T17:58:03Z
# 16   3tQx1LPXbsYjE9VwN1Peaa         Marc E. Bassy  2018-12-01T17:58:03Z
# 17   02kJSzxNuaWGqwubyUba0Z                G-Eazy  2018-12-01T17:58:03Z
# 18   7Ln80lUS6He07XvHI8qqHH        Arctic Monkeys  2018-12-01T17:58:03Z
# 19   246dkjvS1zLTtiykXe5h60           Post Malone  2018-12-01T17:58:03Z
# 20   0VRj0yCOv2FXJNP47XQnx5                 Quavo  2018-12-01T17:58:03Z
# 21   4UXqAaa6dQYAk18Lv7PEgX          Fall Out Boy  2018-12-01T17:58:03Z
# 22   2l35CQqtYRh3d8ZIiBep4v                  MKTO  2018-12-01T17:58:03Z
# 23   7gP3bB2nilZXLfPHJhMdvc     Foster The People  2018-12-01T17:58:03Z
# 24   74XFHRwlV6OrjEM0A2NCMF              Paramore  2018-12-01T17:58:03Z
# 25   0hEurMDQu99nJRq8pTxO14            John Mayer  2018-12-01T17:58:03Z
# 26   7Ln80lUS6He07XvHI8qqHH        Arctic Monkeys  2018-12-01T17:58:03Z
# 27   2FXC3k01G6Gw61bmprjgqS                Hozier  2018-12-01T17:58:03Z
# 28   53XhwfbYqKCa1cC15pYq2q       Imagine Dragons  2018-12-01T17:58:03Z
# 29   7xEFii6utZmQ61kX59HmLH              FRENSHIP  2018-12-01T17:58:03Z
# ..                      ...                   ...                   ...
# 97   3FUY2gzHeIiaesXtOAdB7A                 Train  2018-12-01T17:58:03Z
# 98   6nxWCVXbOlEVRexSbLsTer                 Flume  2018-12-01T17:58:03Z
# 99   6xHUXzrfhFgnIv86EBR3Ml                   Kai  2018-12-01T17:58:03Z
# 100  63bCkf4n15jiKjHhLV7kSZ         Niykee Heaton  2018-12-01T17:58:03Z
# 101  6oMuImdp5ZcFhWP0ESe6mG                 Migos  2018-12-01T17:58:03Z
# 102  5hhgghBFkLDdMn93GW4x3I             OG Parker  2018-12-01T17:58:03Z
# 103  4gzpq5DPGxSnKTe4SA8HAU              Coldplay  2018-12-01T17:58:03Z
# 104  3tLYpanVDomWAZqF82NPds              Vigiland  2018-12-01T17:58:03Z
# 105  2ysnwxxNtSgbb9t1m2Ur4j           George Ezra  2018-12-01T17:58:03Z
# 106  5Pwc4xIPtQLFEnJriah9YJ           OneRepublic  2018-12-01T17:58:03Z
# 107  63MQldklfxkjYDoUE4Tppz                   M83  2018-12-01T17:58:03Z
# 108  1GxkXlMwML1oSg5eLPiAz3         Michael Bublé  2018-12-01T17:58:03Z
# 109  3AQRLZ9PuTAozP28Skbq8V            The Script  2018-12-01T17:58:03Z
# 110  085pc2PYOi8bGKj0PNjekA             will.i.am  2018-12-01T17:58:03Z
# 111  2ysnwxxNtSgbb9t1m2Ur4j           George Ezra  2018-12-01T17:58:03Z
# 112  0bdfiayQAKewqEvaU6rXCv                    MØ  2018-12-01T17:58:03Z
# 113  4ehtJnVumNf6xzSCDk8aLB         Martin Jensen  2018-12-01T17:58:03Z
# 114  6DIS6PRrLS3wbnZsf7vYic         WALK THE MOON  2018-12-01T17:58:03Z
# 115  6eUKZXaKkcviH0Ku9w2n3V            Ed Sheeran  2018-12-01T17:58:03Z
# 116  4gzpq5DPGxSnKTe4SA8HAU              Coldplay  2018-12-01T17:58:03Z
# 117  246dkjvS1zLTtiykXe5h60           Post Malone  2018-12-01T17:58:03Z
# 118  1URnnhqYAYcrqrcwql10ft             21 Savage  2018-12-01T17:58:03Z
# 119  4Rxn7Im3LGfyRkY2FlHhWi            Nick Jonas  2018-12-01T17:58:03Z
# 120  4NHQUGzhtTLFvgF5SZesLK               Tove Lo  2018-12-01T17:58:03Z
# 121  5ndkK3dpZLKtBklKjxNQwT                 B.o.B  2018-12-01T17:58:03Z
# 122  6Rx1JKzBrSzoKQtmbVmBnM       Hayley Williams  2018-12-01T17:58:03Z
# 123  25u4wHJWxCA9vO0CzxAbK7          Lukas Graham  2018-12-01T17:58:03Z
# 124  04gDigrS5kc9YWfZHwBETP              Maroon 5  2018-12-01T17:58:03Z
# 125  6LqNN22kT3074XbTVUrhzX                 Kesha  2018-12-01T17:58:03Z
# 126  1PbBg2aYjWLKRk84zJK15x             Echosmith  2018-12-01T17:58:03Z
#
#      track.popularity                track.id  \
# 0                  62  3x7NGlfDKQYN2wnwEnL7r9
# 1                  75  7lGKEWMXVWWTt3X71Bv44I
# 2                  56  7lrDNvF3TwuC5vC2fGiMjy
# 3                  68  2PwXOevGUSkU8qaYZjgLq2
# 4                  86  75ZvA4QfFiZvzhj2xkaWAh
# 5                  68  1qfYG2JrchEyJiqKnkE7YQ
# 6                  76  4h0zU3O9R5xzuTmNO7dNDU
# 7                  28  6uEIbSu5Omm6Rg2hcVrfJH
# 8                  69  7jDe24vXWUNX8Jl2hZHrIS
# 9                  78  1almCHdsfikRPfVB9VrEdT
# 10                 75  086myS9r57YsLbJpU0TgK9
# 11                 76  3cNjgVBKTJ1SvKhunrCdVy
# 12                 74  7yq4Qj7cqayVTp3FF9CWbm
# 13                 76  15vzANxN8G9wWfwAJLLMCg
# 14                 67  2i0AUcEnsDm3dsqLrFWUCq
# 15                 29  5fX2oPyLCe5mBKqGDbOWqC
# 16                 10  0qRZ9ydGdzeVk3S01pLGoJ
# 17                 10  0qRZ9ydGdzeVk3S01pLGoJ
# 18                 76  2AT8iROs4FQueDv2c8q2KE
# 19                 84  3a1lNhkSLSkpJE4MSHpDu9
# 20                 84  3a1lNhkSLSkpJE4MSHpDu9
# 21                 77  04aAxqtGp5pv12UXAg4pkq
# 22                 73  6FE2iI43OZnszFLuLtvvmg
# 23                  8  52z0MmFwjQZAmXgIYL2hHj
# 24                 70  1j8z4TTjJ1YOdoFEDwJTQa
# 25                 66  0j2WBxWZnWti5TpSxjJvPb
# 26                 42  2UzMpPKPhbcC8RbsmuURAZ
# 27                 12  75aM5sH14TfMYSDLxrfDNW
# 28                 28  2Oehrcv4Kov0SuIgWyQY9e
# 29                 16  3GBlLqIYgB8zWaeWDNJzdh
# ..                ...                     ...
# 97                 79  4HlFJV71xXKIGcU3kRyttv
# 98                 62  12REd1n8PeiHHWOh066tpr
# 99                 62  12REd1n8PeiHHWOh066tpr
# 100                12  3rvLfPT9sm9UPeIr8OQA65
# 101                12  3rvLfPT9sm9UPeIr8OQA65
# 102                12  3rvLfPT9sm9UPeIr8OQA65
# 103                66  1yqMgZNrevsWMLWfO2PRp5
# 104                21  7HGHhLbAklVxGkYdwyeVML
# 105                75  7GJClzimvMSghjcrKxuf1M
# 106                16  519uJbE3zyKLlToVA65PrP
# 107                 5  6M9DkAAuh4ibDchrc8GBAn
# 108                67  0mvkwaZMP2gAy2ApQLtZRv
# 109                76  7wMq5n8mYSKlQIGECKUgTX
# 110                76  7wMq5n8mYSKlQIGECKUgTX
# 111                15  7vjjfdum71w8bbkNSQdnDL
# 112                70  4qqArAiTPueDxIp7cf87h7
# 113                26  6HUnnBwYZqcED1eQztxMBN
# 114                13  79m3gsQ2Ab1bhADmew8N2L
# 115                68  5v4sZRuvWDcisoOk1PFv6T
# 116                68  6f49kbOuQSOsStBpyGvQfA
# 117                26  7wGoVu4Dady5GV0Sv4UIsx
# 118                26  7wGoVu4Dady5GV0Sv4UIsx
# 119                60  2wJhFcye5iiW2mVBpGednz
# 120                60  2wJhFcye5iiW2mVBpGednz
# 121                72  6lV2MSQmRIkycDScNtrBXO
# 122                72  6lV2MSQmRIkycDScNtrBXO
# 123                44  4WuztIKoJkauutLvADtslF
# 124                 9  0DKT3yIip1M0W0J1HYS1ru
# 125                55  3uoQULcUWfnt6nc6J7Vgai
# 126                68  13P5rwmk2EsoFRIz9UCeh9
#
#                                    track.name  track.duration_ms
# 0                     The Kids Aren't Alright             260920
# 1                                    Unsteady             193546
# 2                                Mess Is Mine             223640
# 3                                  All I Want             305746
# 4                                I Fall Apart             223346
# 5                               What You Know             189693
# 6                                    Lost Boy             275280
# 7                                     Georgia             230506
# 8                                  High Hopes             230266
# 9                          Little Do You Know             185200
# 10   Why'd You Only Call Me When You're High?             161123
# 11                            Please Don't Go             210580
# 12                                    Riptide             204280
# 13                                      Paris             221520
# 14                            Tonight Tonight             200466
# 15                      When You Love Someone             216373
# 16                                   You & Me             218480
# 17                                   You & Me             218480
# 18                                  R U Mine?             201726
# 19                            Congratulations             220293
# 20                            Congratulations             220293
# 21                                  Centuries             228360
# 22                                    Classic             175426
# 23                            Pumped Up Kicks             233280
# 24                               Ain't It Fun             296520
# 25                        Love on the Weekend             212626
# 26                           Do I Wanna Know?             272386
# 27                                Someone New             224840
# 28                                     Demons             175200
# 29                                    Capsize             237760
# ..                                        ...                ...
# 97                           Hey, Soul Sister             216773
# 98                          Never Be Like You             233337
# 99                          Never Be Like You             233337
# 100                            Bad Intentions             245722
# 101                            Bad Intentions             245722
# 102                            Bad Intentions             245722
# 103                             Charlie Brown             285159
# 104                              Friday Night             173871
# 105                                  Budapest             200720
# 106                            Counting Stars             257266
# 107                             Midnight City             243960
# 108                      It's A Beautiful Day             199266
# 109                              Hall of Fame             202533
# 110                              Hall of Fame             202533
# 111                            Blame It on Me             196626
# 112                                Final Song             235826
# 113                                Solo Dance             174933
# 114                         Shut Up and Dance             198720
# 115                               Bloodstream             300253
# 116                     A Head Full Of Dreams             223773
# 117                                  rockstar             218320
# 118                                  rockstar             218320
# 119                                     Close             234213
# 120                                     Close             234213
# 121         Airplanes (feat. Hayley Williams)             180480
# 122         Airplanes (feat. Hayley Williams)             180480
# 123                             Strip No More             207500
# 124                                      Maps             189973
# 125                      Your Love Is My Drug             187133
# 126                                 Cool Kids             237626
#
# [127 rows x 7 columns]

# %%
json_data = r_10s.json()
playlists_10 = json_normalize(json_data["tracks"]["items"], [['track', 'artists']], ['added_at', ['track', 'popularity'], ['track', 'id'], ['track', 'name'], ['track', 'duration_ms']], errors='ignore')
playlists_10 = playlists_10.drop(columns=['external_urls', 'href', 'type', 'uri'])

json_data_00 = r_00s.json()
playlists_00 = json_normalize(json_data_00["tracks"]["items"], [['track', 'artists']], ['added_at', ['track', 'popularity'], ['track', 'id'], ['track', 'name'], ['track', 'duration_ms']], errors='ignore')
playlists_00 = playlists_00.drop(columns=['external_urls', 'href', 'type', 'uri'])

json_data_90 = r_90s.json()
playlists_90 = json_normalize(json_data_90["tracks"]["items"], [['track', 'artists']], ['added_at', ['track', 'popularity'], ['track', 'id'], ['track', 'name'], ['track', 'duration_ms']], errors='ignore')
playlists_90 = playlists_90.drop(columns=['external_urls', 'href', 'type', 'uri'])

json_data_80 = r_80s.json()
playlists_80 = json_normalize(json_data_80["tracks"]["items"], [['track', 'artists']], ['added_at', ['track', 'popularity'], ['track', 'id'], ['track', 'name'], ['track', 'duration_ms']], errors='ignore')
playlists_80 = playlists_80.drop(columns=['external_urls', 'href', 'type', 'uri'])

json_data_70 = r_70s.json()
playlists_70 = json_normalize(json_data_70["tracks"]["items"], [['track', 'artists']], ['added_at', ['track', 'popularity'], ['track', 'id'], ['track', 'name'], ['track', 'duration_ms']], errors='ignore')
playlists_70 = playlists_70.drop(columns=['external_urls', 'href', 'type', 'uri'])

json_data_60 = r_60s.json()
playlists_60 = json_normalize(json_data_60["tracks"]["items"], [['track', 'artists']], ['added_at', ['track', 'popularity'], ['track', 'id'], ['track', 'name'], ['track', 'duration_ms']], errors='ignore')
playlists_60 = playlists_60.drop(columns=['external_urls', 'href', 'type', 'uri'])

json_data_50 = r_50s.json()
playlists_50 = json_normalize(json_data_50["tracks"]["items"], [['track', 'artists']], ['added_at', ['track', 'popularity'], ['track', 'id'], ['track', 'name'], ['track', 'duration_ms']], errors='ignore')
playlists_50 = playlists_50.drop(columns=['external_urls', 'href', 'type', 'uri'])

playlists_80
# Out:
#                          id                         name  \
# 0    0PFtn5NtBbbUNbU9EAmIWF                         Toto
# 1    4QTVePrFu1xuGM9K0kNXkk       Dexys Midnight Runners
# 2    77tT1kLj6mCWtFNqiOmP9H      Daryl Hall & John Oates
# 3    6zFYqv1mOsgBRQbae3JJ9e                   Billy Joel
# 4    6IFXsrXBpwbIqtOUOiAa3p             Rick Springfield
# 5    4bthk9UfsYUYdcFyqxmSUU              Tears For Fears
# 6    3RGLhK1IP9jnYFH4BRFJBS                    The Clash
# 7    2hO4YtXUFJiUYS2uYFvHNK           Traveling Wilburys
# 8    2UZMlIwnkgAEDBsw1Rejkn                    Tom Petty
# 9    77tT1kLj6mCWtFNqiOmP9H      Daryl Hall & John Oates
# 10   0rvjqX7ttXeg3mTy8Xscbt                      Journey
# 11   2jzc5TC5TVFLXQlBNiIUzE                         a-ha
# 12   3lPQ2Fk5JOwGWAF3ORFCqH              John Mellencamp
# 13   6H1RjVyNruCmrBEWRbD0VZ                  Def Leppard
# 14   2UZMlIwnkgAEDBsw1Rejkn                    Tom Petty
# 15   69Mj3u4FTUrpyeGNSIaU6F            The J. Geils Band
# 16   1A92IAcd7A6npCA33oGM5i              The Proclaimers
# 17   0rvjqX7ttXeg3mTy8Xscbt                      Journey
# 18   6H1RjVyNruCmrBEWRbD0VZ                  Def Leppard
# 19   1zxDewzd2j1ZdSBGaYcr0y                 The Outfield
# 20   1Fmb52lZ6Jv7FMWXXTPO3K  Joan Jett & The Blackhearts
# 21   1dfeR4HaWDbWqFHLkxsg1d                        Queen
# 22   3bmFPbLMiLxtR9tFrTcKcP               Matthew Wilder
# 23   0J2Ej2rMQyqaUX3G6MUISw                     Ambrosia
# 24   0PFtn5NtBbbUNbU9EAmIWF                         Toto
# 25   0kObWap02DEg9EAJ3PBxzf                     Starship
# 26   1dfeR4HaWDbWqFHLkxsg1d                        Queen
# 27   7FIoB5PHdrMZVC3q2HE5MS              George Harrison
# 28   5NGO30tJxFlKixkPSgXcFE                   The Police
# 29   58lV9VcRSjABbAbfWS6skp                     Bon Jovi
# ..                      ...                          ...
# 72   3qm84nBOXUEQ2vnTfUTTFC                Guns N' Roses
# 73   6XpaIBNiVzIetEPCWDvAFP              Whitney Houston
# 74   77tT1kLj6mCWtFNqiOmP9H      Daryl Hall & John Oates
# 75   3fMbdgg4jU18AjLCKBhRSm              Michael Jackson
# 76   7b85ve82Sh36a3UAx74wut               Twisted Sister
# 77   3qm84nBOXUEQ2vnTfUTTFC                Guns N' Roses
# 78   3CkvROUTQ6nRi9yQOcsB50                      Genesis
# 79   4bthk9UfsYUYdcFyqxmSUU              Tears For Fears
# 80   73a6pNH4YtLNgDbPQwXveo                    Kim Wilde
# 81   4AYkFtEBnNnGuoo8HaHErd                      Madness
# 82   0xliTEbFfy5HQHvsTknTkX                   Alphaville
# 83   7sF6m3PpW6G6m6J2gzzmzM            U.S.A. For Africa
# 84   3cniTumSiUysiPWXapGx1i                 Cutting Crew
# 85   2tRsMl4eGxwoNabM08Dm4I                 Judas Priest
# 86   7bu3H8JO7d0UbMoVzbo70s                     The Cure
# 87   32vWCbZh0xZ4o9gkz4PsEU                 Dolly Parton
# 88   7A9yZMTrFZcgEWAX2kBfK6        Huey Lewis & The News
# 89   2AM4ilv6UzW0uMRuqKtDgN                       ZZ Top
# 90   51Blml2LZPmy7TTiAg47vQ                           U2
# 91   0LcJLqbBmaGUft1e9Mm8HV                         ABBA
# 92   0WwSkZ7LtFUFjGjMZBMt6T                 Dire Straits
# 93   1fBCIkoPOPCDLUxGuWNvyo                       Poison
# 94   3Z02hBLubJxuFJfhacLSDc                  Bryan Adams
# 95   3mQBpAOMWYqAZyxtyeo4Lo       KC & The Sunshine Band
# 96   3iUjRVvYCsMfz7tuAQtBDI                     Ultravox
# 97   5gxynDEKwNDgxGJmJjZyte                Steve Winwood
# 98   7fIvjotigTGWqjIz6EP1i4                    Four Tops
# 99   5PN2aHIvLEM98XIorsPMhE                   Kim Carnes
# 100  0amM1FQK5y3Hdk8Rxxhgi0                 Donald Lynch
# 101  4xJcs1av5wEFcu7sIGMcRl                 Marc Andrews
#
#                  added_at  track.popularity                track.id  \
# 0    2018-12-01T18:05:10Z                66  5tJjo5JDF9zhzYD7yQfATH
# 1    2018-12-01T18:05:10Z                28  5uzNa0SBGOe5pPnstWHMCt
# 2    2018-12-01T18:05:10Z                76  4o6BgsqLIBViaGVbx5rbRk
# 3    2018-12-01T18:05:10Z                74  5zA8vzDGqPl2AzZkEYQGKh
# 4    2018-12-01T18:05:10Z                60  2F1fnE1a8zQCogM6jJifHH
# 5    2018-12-01T18:05:10Z                78  4RvWPyQ5RL0ao9LPZeSouE
# 6    2018-12-01T18:05:10Z                76  39shmbIHICJ2Wxnk1fPSdz
# 7    2018-12-01T18:05:10Z                65  4HA2jo7wkMdN1lmLO6ryzE
# 8    2018-12-01T18:05:10Z                59  0Ir0Esfpcg0EB6Kq8VbbAh
# 9    2018-12-01T18:05:10Z                60  5HQ639Z3ms3hnZx0KfWnkp
# 10   2018-12-01T18:05:10Z                67  71SvEDmsOwIWw1IozsZoMA
# 11   2018-12-01T18:05:10Z                81  2WfaOiMkCvy7F5fcp2zZ8L
# 12   2018-12-01T18:05:10Z                67  43btz2xjMKpcmjkuRsvxyg
# 13   2018-12-01T18:05:10Z                16  5L4kmSZOSjaoUEzrFqQadT
# 14   2018-12-01T18:05:10Z                69  7woZGXjtaYwuvSoU1zToB3
# 15   2018-12-01T18:05:10Z                68  1ynmMEK1fkyiZ6Z6F3ThEt
# 16   2018-12-01T18:05:10Z                73  66S14BkJDxgkYxLl5DCqOz
# 17   2018-12-01T18:05:10Z                76  4bHsxqR3GMrXTxEPLuK5ue
# 18   2018-12-01T18:05:10Z                66  2PFIZFcGry0po3ZfRZkzKc
# 19   2018-12-01T18:05:10Z                69  5dRQUolXAVX3BbCiIxmSsf
# 20   2018-12-01T18:05:10Z                14  5qtLQt2iDjZyDpvpuSqeYi
# 21   2018-12-01T18:05:10Z                84  5vdp5UmvTsnMEMESIF2Ym7
# 22   2018-12-01T18:05:10Z                58  2ZqT3GcisHUBsEaqhLGHwU
# 23   2018-12-01T18:05:10Z                62  6JHXiRD1QjMK1N6AQEnL04
# 24   2018-12-01T18:05:10Z                58  65vEK65KeqeH11s3Ym8BWO
# 25   2018-12-01T18:05:10Z                71  7aHRctaQ7vjxVTVmY8OhAA
# 26   2018-12-01T18:05:10Z                19  3mvoMBK8QDtnhz8U2L2XK2
# 27   2018-12-01T18:05:10Z                64  6miUySWi347iIJyz7ETo6m
# 28   2018-12-01T18:05:10Z                65  60HDLY1Dh2Hy9wTVI3WPzO
# 29   2018-12-01T18:05:10Z                21  5VVwwfK6Cp9IydkhKfJUEq
# ..                    ...               ...                     ...
# 72   2018-12-01T18:05:10Z                75  3YBZIN3rekqsKxbJc9FZko
# 73   2018-12-01T18:05:10Z                78  2tUBqZG2AbRi7Q0BIrVrEj
# 74   2018-12-01T18:05:10Z                72  4aKIs5t9TqP59btlCGPrgw
# 75   2018-12-01T18:05:10Z                74  2bCQHF9gdG5BNDVuEIEnNk
# 76   2018-12-01T18:05:10Z                69  1hlveB9M6ijHZRbzZ2teyh
# 77   2018-12-01T18:05:10Z                75  0bVtevEgtDIeRjCJbK3Lmv
# 78   2018-12-01T18:05:10Z                63  480dDrqG7LO6qDaphHeXlM
# 79   2018-12-01T18:05:10Z                66  2gQaQUhDCNGfBVXTvxAmXQ
# 80   2018-12-01T18:05:10Z                64  1YGZyfvdgZxzipWoWYVKxi
# 81   2018-12-01T18:05:10Z                58  0BTsVL5VMdq5zGNRSTHozJ
# 82   2018-12-01T18:05:10Z                73  4S1VYqwfkLit9mKVY3MXoo
# 83   2018-12-01T18:05:10Z                66  3Z2tPWiNiIpg8UMMoowHIk
# 84   2018-12-01T18:05:10Z                68  0YPXkQthLWrhNGoKTbwCJ8
# 85   2018-12-01T18:05:10Z                61  4f3RDq9nYPBeR1yMSgnmBm
# 86   2018-12-01T18:05:10Z                57  1YQCRXscu8xE74BVVMUCRr
# 87   2018-12-01T18:05:10Z                71  4w3tQBXhn5345eUXDGBWZG
# 88   2018-12-01T18:05:10Z                61  648BMGrt98kUbLo24A4vgj
# 89   2018-12-01T18:05:10Z                69  1UBQ5GK8JaQjm5VbkBZY66
# 90   2018-12-01T18:05:10Z                60  2x45xqISlmmDJqxOqr8BuS
# 91   2018-12-01T18:05:10Z                23  5kBZR12AntJUTo9UeAsKqP
# 92   2018-12-01T18:05:10Z                27  4tyl9OMKMG8F2L0RUYQMH3
# 93   2018-12-01T18:05:10Z                68  43GS3mtezoIFiuIZCLLiDY
# 94   2018-12-01T18:05:10Z                72  7Ewz6bJ97vUqk5HdkvguFQ
# 95   2018-12-01T18:05:10Z                61  40QPoAAKKMwPms6I6FHJqy
# 96   2018-12-01T18:05:10Z                60  42l1eOB0qSkTxHdEZEhqem
# 97   2018-12-01T18:05:10Z                63  3nQuDlaVZApyrG6tdsETe0
# 98   2018-12-01T18:05:10Z                59  7gfAYm7X5HMSuKcO4dy8Wi
# 99   2018-12-01T18:05:10Z                23  5i7GFU1ZSX03MX5dLcNgJP
# 100  2018-12-01T18:05:10Z                23  5i7GFU1ZSX03MX5dLcNgJP
# 101  2018-12-01T18:05:10Z                23  5i7GFU1ZSX03MX5dLcNgJP
#
#                                             track.name  track.duration_ms
# 0                                               Africa             296000
# 1                                       Come On Eileen             273720
# 2                                   You Make My Dreams             190626
# 3                                          Uptown Girl             197706
# 4                                        Jessie's Girl             194266
# 5                    Everybody Wants To Rule The World             251488
# 6            Should I Stay or Should I Go - Remastered             188986
# 7                                      End Of The Line             209520
# 8                                    I Won't Back Down             175733
# 9                            Private Eyes - Remastered             217200
# 10                                 Any Way You Want It             201693
# 11                                          Take On Me             225280
# 12                                        Jack & Diane             254493
# 13                               Pour Some Sugar On Me             267306
# 14                                        Free Fallin'             256666
# 15                                          Centerfold             216533
# 16                            I'm Gonna Be (500 Miles)             219466
# 17                                Don't Stop Believin'             250986
# 18                                            Hysteria             354636
# 19                                           Your Love             221840
# 20                                 I Love Rock n' Roll             175733
# 21        Another One Bites The Dust - Remastered 2011             214653
# 22                                     Break My Stride             180240
# 23                                  Biggest Part Of Me             324040
# 24                                             Rosanna             330986
# 25                                  We Built This City             296080
# 26                                I Want To Break Free             201000
# 27           Got My Mind Set On You - Extended Version             317289
# 28   Every Little Thing She Does Is Magic - Remaste...             259500
# 29                            You Give Love A Bad Name             222706
# ..                                                 ...                ...
# 72                                       Paradise City             405640
# 73          I Wanna Dance with Somebody (Who Loves Me)             291293
# 74                                            Maneater             271893
# 75                     Smooth Criminal - 2012 Remaster             257760
# 76                             We're Not Gonna Take It             219666
# 77                               Welcome To The Jungle             272026
# 78                   Invisible Touch - Remastered 2007             210133
# 79                                               Shout             393666
# 80                                     Kids In America             205533
# 81                                           Our House             190840
# 82                                       Forever Young             226706
# 83                                    We Are The World             427333
# 84                          (I Just) Died In Your Arms             278626
# 85                     You've Got Another Thing Coming             310080
# 86                                      Boys Don't Cry             154666
# 87                                              9 to 5             162466
# 88                                    Hip To Be Square             245466
# 89         Sharp Dressed Man - 2008 Remastered Version             258026
# 90                    With Or Without You - Remastered             295520
# 91                             The Winner Takes It All             294720
# 92                                        Walk Of Life             249960
# 93          Every Rose Has Its Thorn - Remastered 2003             260173
# 94                                              Heaven             243360
# 95                                          Give It Up             245800
# 96                       Dancing with Tears in My Eyes             244120
# 97                                             Valerie             246666
# 98                                    Loco in Acapulco             274066
# 99   Bette Davis Eyes - Radio Edit; 1997 Remastered...             221773
# 100  Bette Davis Eyes - Radio Edit; 1997 Remastered...             221773
# 101  Bette Davis Eyes - Radio Edit; 1997 Remastered...             221773
#
# [102 rows x 7 columns]

# %%
aggregation_functions = {'name': 'first', 'track.id': 'first', 'track.duration_ms': 'first', 'added_at': 'first', 'track.popularity' : 'first'}
df_new = playlists_10.groupby(playlists_10['track.name']).aggregate(aggregation_functions)

aggregation_functions = {'name': 'first', 'track.id': 'first', 'track.duration_ms': 'first', 'added_at': 'first', 'track.popularity' : 'first'}
grouped_00 = playlists_00.groupby(playlists_00['track.name']).aggregate(aggregation_functions)

aggregation_functions = {'name': 'first', 'track.id': 'first', 'track.duration_ms': 'first', 'added_at': 'first', 'track.popularity' : 'first'}
grouped_90 = playlists_90.groupby(playlists_90['track.name']).aggregate(aggregation_functions)

aggregation_functions = {'name': 'first', 'track.id': 'first', 'track.duration_ms': 'first', 'added_at': 'first', 'track.popularity' : 'first'}
grouped_80 = playlists_80.groupby(playlists_80['track.name']).aggregate(aggregation_functions)

aggregation_functions = {'name': 'first', 'track.id': 'first', 'track.duration_ms': 'first', 'added_at': 'first', 'track.popularity' : 'first'}
grouped_70 = playlists_70.groupby(playlists_70['track.name']).aggregate(aggregation_functions)

aggregation_functions = {'name': 'first', 'track.id': 'first', 'track.duration_ms': 'first', 'added_at': 'first', 'track.popularity' : 'first'}
grouped_60 = playlists_60.groupby(playlists_60['track.name']).aggregate(aggregation_functions)

aggregation_functions = {'name': 'first', 'track.id': 'first', 'track.duration_ms': 'first', 'added_at': 'first', 'track.popularity' : 'first'}
grouped_50 = playlists_50.groupby(playlists_50['track.name']).aggregate(aggregation_functions)

# %%
track_ids = df_new['track.id'].tolist()
track_str = '%2C'.join(track_ids)
t = requests.get("https://api.spotify.com/v1/audio-features?ids=" + track_str, headers={'Authorization': 'Bearer ' + token})
track_info_df = json_normalize(t.json()['audio_features'])
track_info_df = track_info_df.drop(columns=['analysis_url', 'mode', 'track_href', 'type', 'uri'])

track_ids_00 = grouped_00['track.id'].tolist()
track_str_00 = '%2C'.join(track_ids_00)
t_00s = requests.get("https://api.spotify.com/v1/audio-features?ids=" + track_str_00, headers={'Authorization': 'Bearer ' + token})
track_info_00 = json_normalize(t_00s.json()['audio_features'])
track_info_00 = track_info_00.drop(columns=['analysis_url', 'mode', 'track_href', 'type', 'uri'])

track_ids_90 = grouped_90['track.id'].tolist()
track_str_90 = '%2C'.join(track_ids_90)
t_90s = requests.get("https://api.spotify.com/v1/audio-features?ids=" + track_str_90, headers={'Authorization': 'Bearer ' + token})
track_info_90 = json_normalize(t_90s.json()['audio_features'])
track_info_90 = track_info_90.drop(columns=['analysis_url', 'mode', 'track_href', 'type', 'uri'])

track_ids_80 = grouped_80['track.id'].tolist()
track_str_80 = '%2C'.join(track_ids_80)
t_80s = requests.get("https://api.spotify.com/v1/audio-features?ids=" + track_str_80, headers={'Authorization': 'Bearer ' + token})
track_info_80 = json_normalize(t_80s.json()['audio_features'])
track_info_80 = track_info_80.drop(columns=['analysis_url', 'mode', 'track_href', 'type', 'uri'])

track_ids_70 = grouped_70['track.id'].tolist()
track_str_70 = '%2C'.join(track_ids_70)
t_70s = requests.get("https://api.spotify.com/v1/audio-features?ids=" + track_str_70, headers={'Authorization': 'Bearer ' + token})
track_info_70 = json_normalize(t_70s.json()['audio_features'])
track_info_70 = track_info_70.drop(columns=['analysis_url', 'mode', 'track_href', 'type', 'uri'])

track_ids_60 = grouped_60['track.id'].tolist()
track_str_60 = '%2C'.join(track_ids_60)
t_60s = requests.get("https://api.spotify.com/v1/audio-features?ids=" + track_str_60, headers={'Authorization': 'Bearer ' + token})
track_info_60 = json_normalize(t_60s.json()['audio_features'])
track_info_60 = track_info_60.drop(columns=['analysis_url', 'mode', 'track_href', 'type', 'uri'])

track_ids_50 = grouped_50['track.id'].tolist()
track_str_50 = '%2C'.join(track_ids_50)
t_50s = requests.get("https://api.spotify.com/v1/audio-features?ids=" + track_str_50, headers={'Authorization': 'Bearer ' + token})
track_info_50 = json_normalize(t_50s.json()['audio_features'])
track_info_50 = track_info_50.drop(columns=['analysis_url', 'mode', 'track_href', 'type', 'uri'])

grouped_50_index = grouped_50.index
grouped_50.index = range(len(grouped_50))
grouped_50["track.name"] = grouped_50_index

grouped_60_index = grouped_60.index
grouped_60.index = range(len(grouped_60))
grouped_60["track.name"] = grouped_60_index

grouped_70_index = grouped_70.index
grouped_70.index = range(len(grouped_70))
grouped_70["track.name"] = grouped_70_index

grouped_80_index = grouped_80.index
grouped_80.index = range(len(grouped_80))
grouped_80["track.name"] = grouped_80_index

grouped_90_index = grouped_90.index
grouped_90.index = range(len(grouped_90))
grouped_90["track.name"] = grouped_90_index

grouped_00_index = grouped_00.index
grouped_00.index = range(len(grouped_00))
grouped_00["track.name"] = grouped_00_index

#track.name appears to be in the index so we need to reindex it
df_index = df_new.index
df_new.index = range(len(df_new))
df_new["track.name"] = df_index

print(grouped_50)
# Out:
#                              name                track.id  track.duration_ms  \
# 0         Bill Haley & His Comets  5PZf7EZr7GfkOAgeEcsqPa             134106
# 1             Dion & The Belmonts  6AhHYWJOBMRjEi2z1tWpYa             153866
# 2                     Fats Domino  4ZfQwNx3FlCN07cnUvekh3             152200
# 3             Danny & The Juniors  6vkuJbGjyjnSQReeaCh8wT             149933
# 4                     The Regents  0Aoh3SQxGdBlxVSXLZUToj             135773
# 5    Gene Vincent & His Blue Caps  0TMrV95mP7sDlvbE4iVfKP             157206
# 6                     Fats Domino  2NkAoxQOr6MGdMB5JDTU81             143440
# 7                   The Monotones  6kIYy84YuKk2dwAZbYJjrG             138986
# 8                     Louis Prima  7LYfx4uOewuMJnkAN4xHlj             180093
# 9             The Everly Brothers  0xK34uEDBKa9ZzJ6kelLJE             142906
# 10                  Eddie Cochran  3kEnKwF8IbvTwUuubZb17q             117666
# 11                The Del-Vikings  4Ul2q7TUVGkHIFyMABAgk6             162293
# 12                 Ritchie Valens  4cRfSR0QxDlXRHTKyEOu93             124586
# 13                      Paul Anka  0STUX1dMWvC7RsyOTTgqxt             136946
# 14                    Bobby Darin  1KLpjQFgubHI3GkAICCNH3             150706
# 15                   Buster Brown  3dMpikgb98W6TmcgkEt1Js             172160
# 16                    Johnny Cash  6pPmgSgrdWMemkmpRWO2aQ             172026
# 17                The Silhouettes  21NhrNOfIoakyWISXUMkFN             169706
# 18                 Little Richard  1fMMRoalpb7E8m5FsAta2y             127386
# 19                   The Spaniels  50meIWPMuhYgQSXfSsUvtI             160373
# 20                Jerry Lee Lewis  1h2NZP7rlDgelQ0r1tCOzs             110653
# 21                     Jim Reeves  7DH5dXVuQaqcKf9oTy9oUN             138640
# 22                   Ricky Nelson  0IMS1Za69G3KHMX4liB2Nr             139280
# 23                  Elvis Presley  0MLpdnTsnnaxH5yEJzxV6I             133293
# 24                    Johnny Cash  7kIDzcFzCSaPLOi4ZMt2Bx             163026
# 25                    Ray Charles  2xar08Fq5xra2KKZs5Bw9j             171466
# 26                  Frank Sinatra  3aEJMh1cXKEjgh52claxQp             223760
# 27                  Elvis Presley  3ZUv7Z20fITqCTzJL9bLP2             155333
# 28                    Fats Domino  1slMt4LizkO9dVcMZItJ1O             144066
# 29                    Chuck Berry  11cPCZ0BYWJmAm7N8eDxtu             161560
# ..                            ...                     ...                ...
# 45                    Chuck Berry  6OrnVjcEwJqEuoG50k4LQ0             142906
# 46                           Dion  1JOir33J9gtVyBN8VsmKqn             160306
# 47                    Del Shannon  0BY6W6PWdlghnZ41Uo5Eyz             139320
# 48                   LaVern Baker  0HsYttDxOv3neiw3L0wimY             149093
# 49        Bill Haley & His Comets  1s4hyUFWmLWiAamsclb4xA             165360
# 50        Bill Haley & His Comets  2JoXjemDQe0fSmk26CpfrP             150466
# 51      Johnny Kidd & The Pirates  2XDQ53SHZfUyX9zzAyUXmN             139733
# 52             The Isley Brothers  4J7VWj4ibCSw3tCiRKpypm             272560
# 53                  The Skyliners  5zgzOyEZPoeQwmXFzW0bPn             156893
# 54           Tennessee Ernie Ford  3P6OwCX7Ofiaaqtvujb6i5             158306
# 55                   The Platters  3z0Fm7pHB6ojjfj8JY6QRW             158546
# 56                 Connie Francis  4C0wRKBEUuYonk1uxXjxGG             136426
# 57                  Eddie Cochran  2wwRSaZgshcHSvGzWryUIi             120000
# 58                      Bobby Vee  1MR7XamWS0XH6vZxeeRdE0             150866
# 59                     Patti Page  7t8Tzd9FqVz2asFMCL0HpZ             183573
# 60                     The Champs  14bUqUj1EUnQabWeAqnj39             130320
# 61                    Buddy Holly  49dOnz1NuDgUNba91MudGy             136800
# 62                    Dean Martin  7ha6LU5Dle7FGBh0I9LZIa             188466
# 63                   The Platters  7DPxY0fRDRHeWRtLZZoOyt             159288
# 64                           Dion  4EoUALVwY4i7U6uKRhk8hr             163626
# 65                The Five Satins  5VyJGb6l6rY8bBZH2RC6XD             165866
# 66                 Little Richard  3Os0VNtvEnRFlXSK5dvOFu             146640
# 67                   The Drifters  5eh0402zJwaohvhArtKhQ4             157640
# 68            The Everly Brothers  7mVbL1b8HC1rW4Jle6ypG3             123000
# 69  Frankie Lymon & The Teenagers  6pqleSjOGb4XP9tjU7IwCv             179466
# 70                Jerry Lee Lewis  6wO13Xb3EdHUNixFOEJ0KV             172400
# 71  Frankie Lymon & The Teenagers  6vL5Kx5LmZzcL12DZl2OiY             138973
# 72                     Lee Dorsey  2pMwweGkjNLXZkSDZ63LYf             146053
# 73                      Sam Cooke  1uaHZMJyULGDBiNa9pk3FV             173026
# 74                Johnny Burnette  5HEDjLbZzujPv6xiylsCQ2             118333
#
#                 added_at  track.popularity  \
# 0   2018-10-02T00:00:48Z                52
# 1   2018-10-02T00:00:48Z                58
# 2   2018-10-02T00:00:48Z                54
# 3   2018-10-02T00:00:48Z                11
# 4   2018-10-02T00:00:48Z                44
# 5   2018-10-02T00:00:48Z                44
# 6   2018-10-02T00:00:48Z                55
# 7   2018-10-02T00:00:48Z                10
# 8   2018-10-02T00:00:48Z                45
# 9   2018-10-02T00:00:48Z                48
# 10  2018-10-02T00:00:48Z                 8
# 11  2018-10-02T00:00:48Z                10
# 12  2018-10-02T00:00:48Z                57
# 13  2018-10-02T00:00:48Z                49
# 14  2018-10-02T00:00:48Z                60
# 15  2018-10-02T00:00:48Z                44
# 16  2018-10-02T00:00:48Z                49
# 17  2018-10-02T00:00:48Z                47
# 18  2018-10-02T00:00:48Z                14
# 19  2018-10-02T00:00:48Z                46
# 20  2018-10-02T00:00:48Z                53
# 21  2018-10-02T00:00:48Z                57
# 22  2018-10-02T00:00:48Z                51
# 23  2018-10-02T00:00:48Z                 9
# 24  2018-10-02T00:00:48Z                48
# 25  2018-10-02T00:00:48Z                65
# 26  2018-10-02T00:00:48Z                66
# 27  2018-10-02T00:00:48Z                10
# 28  2018-10-02T00:00:48Z                 8
# 29  2018-10-02T00:00:48Z                12
# ..                   ...               ...
# 45  2018-10-02T00:00:48Z                11
# 46  2018-10-02T00:00:48Z                13
# 47  2018-10-02T00:00:48Z                49
# 48  2018-10-02T00:00:48Z                48
# 49  2018-10-02T00:00:48Z                49
# 50  2018-10-02T00:00:48Z                57
# 51  2018-10-02T00:00:48Z                41
# 52  2018-10-02T00:00:48Z                48
# 53  2018-10-02T00:00:48Z                 8
# 54  2018-10-02T00:00:48Z                55
# 55  2018-10-02T00:00:48Z                42
# 56  2018-10-02T00:00:48Z                45
# 57  2018-10-02T00:00:48Z                14
# 58  2018-10-02T00:00:48Z                58
# 59  2018-10-02T00:00:48Z                 7
# 60  2018-10-02T00:00:48Z                54
# 61  2018-10-02T00:00:48Z                54
# 62  2018-10-02T00:00:48Z                59
# 63  2018-10-02T00:00:48Z                48
# 64  2018-10-02T00:00:48Z                63
# 65  2018-10-02T00:00:48Z                45
# 66  2018-10-02T00:00:48Z                10
# 67  2018-10-02T00:00:48Z                53
# 68  2018-10-02T00:00:48Z                45
# 69  2018-10-02T00:00:48Z                42
# 70  2018-10-02T00:00:48Z                58
# 71  2018-10-02T00:00:48Z                52
# 72  2018-10-02T00:00:48Z                48
# 73  2018-10-02T00:00:48Z                 8
# 74  2018-10-02T00:00:48Z                 7
#
#                                            track.name
# 0   (We're Gonna) Rock Around The Clock - Single V...
# 1                                  A Teenager In Love
# 2                                  Ain't That A Shame
# 3                                          At The Hop
# 4                                         Barbara-Ann
# 5                                       Be-Bop-A-Lula
# 6                    Blueberry Hill - Remastered 2002
# 7                       Book Of Love - Single Version
# 8                        Buona Sera - Remastered 2002
# 9                                        Bye Bye Love
# 10                                    C'mon Everybody
# 11                                    Come Go With Me
# 12                                  Come On, Let's Go
# 13                                              Diana
# 14                                        Dream Lover
# 15                                         Fannie Mae
# 16                                Folsom Prison Blues
# 17                                          Get a Job
# 18                              Good Golly Miss Molly
# 19  Goodnite, It's Time to Go (Goodnight Sweethear...
# 20          Great Balls Of Fire - 1963 Stereo Version
# 21                                   He'll Have to Go
# 22                     Hello Mary Lou (Goodbye Heart)
# 23                                          Hound Dog
# 24                   I Walk The Line - Single Version
# 25                                   I've Got A Woman
# 26       I've Got You Under My Skin - Remastered 1998
# 27                                     Jailhouse Rock
# 28                           Jambalaya (On The Bayou)
# 29                   Johnny B. Goode - Single Version
# ..                                                ...
# 45               Roll Over Beethoven - Single Version
# 46                    Runaround Sue - Remastered 1991
# 47                  Runaway - 2004 Remastered Version
# 48                                      See See Rider
# 49                           See You Later, Alligator
# 50            Shake, Rattle And Roll - Single Version
# 51         Shakin' All Over - 2004 Remastered Version
# 52                                              Shout
# 53                             Since I Don't Have You
# 54                                       Sixteen Tons
# 55           Smoke Gets In Your Eyes - Single Version
# 56                                       Stupid Cupid
# 57                                   Summertime Blues
# 58        Take Good Care Of My Baby - 1990 Remastered
# 59                                    Tennessee Waltz
# 60                                 Tequila (Original)
# 61                                 That'll Be The Day
# 62               That's Amore - 1996 Digital Remaster
# 63               The Great Pretender - Single Version
# 64                                       The Wanderer
# 65                                       To The Aisle
# 66                                       Tutti Frutti
# 67                                Under the Boardwalk
# 68     Wake Up Little Susie - 2006 Remastered Version
# 69  Who Put The Bomp (In The Bomp Bomp Bomp) - 200...
# 70                      Whole Lot of Shakin' Going On
# 71                          Why Do Fools Fall in Love
# 72                                              Ya Ya
# 73                                        You Send Me
# 74  You're Sixteen-Your're Beautiful (And You're M...
#
# [75 rows x 6 columns]

# %%
data_2010s = pd.merge(df_new, track_info_df, left_on = 'track.id', right_on = 'id')
data_2000s = pd.merge(grouped_00, track_info_00, left_on = 'track.id', right_on = 'id')
data_1990s = pd.merge(grouped_90, track_info_90, left_on = 'track.id', right_on = 'id')
data_1980s = pd.merge(grouped_80, track_info_80, left_on = 'track.id', right_on = 'id')
data_1970s = pd.merge(grouped_70, track_info_70, left_on = 'track.id', right_on = 'id')
data_1960s = pd.merge(grouped_60, track_info_60, left_on = 'track.id', right_on = 'id')
data_1950s = pd.merge(grouped_50, track_info_50, left_on = 'track.id', right_on = 'id')

# %%
data_2010s['decade'] = '2010s'
data_2000s['decade'] = '2000s'
data_1990s['decade'] = '1990s'
data_1980s['decade'] = '1980s'
data_1970s['decade'] = '1970s'
data_1960s['decade'] = '1960s'
data_1950s['decade'] = '1950s'

# %%
decades_data = pd.concat([data_2010s, data_2000s, data_1990s, data_1980s, data_1970s, data_1960s, data_1950s])
decades_data['energy'].groupby(decades_data['decade']).describe()
# fixing the index
decades_data.index = range(len(decades_data))
decades_data # if track name doesn't show up, just restart the kernel
# Out:
#                               name                track.id  track.duration_ms  \
# 0                         Coldplay  6f49kbOuQSOsStBpyGvQfA             223773
# 1                         Paramore  1j8z4TTjJ1YOdoFEDwJTQa             296520
# 2                            B.o.B  6lV2MSQmRIkycDScNtrBXO             180480
# 3                         Kodaline  2PwXOevGUSkU8qaYZjgLq2             305746
# 4                        Snakehips  6TaqooOXAEcijL6G1AWS2K             229746
# 5                    Niykee Heaton  3rvLfPT9sm9UPeIr8OQA65             245722
# 6                   Mumford & Sons  7HqtFBLJcilvyUuMav4Y5W             220866
# 7                 American Authors  5j9iuo3tMmQIfnEEQOOjxh             194240
# 8                      George Ezra  7vjjfdum71w8bbkNSQdnDL             196626
# 9                  Raleigh Ritchie  7EHv6Eb7nQOXhO0BW5gytT             259133
# 10                      Ed Sheeran  5v4sZRuvWDcisoOk1PFv6T             300253
# 11                     George Ezra  7GJClzimvMSghjcrKxuf1M             200720
# 12                        FRENSHIP  3GBlLqIYgB8zWaeWDNJzdh             237760
# 13                      Ed Sheeran  6PCUP3dWmTjcTtXY02oFdT             261153
# 14                    Fall Out Boy  04aAxqtGp5pv12UXAg4pkq             228360
# 15                        Coldplay  1yqMgZNrevsWMLWfO2PRp5             285159
# 16                            MKTO  6FE2iI43OZnszFLuLtvvmg             175426
# 17                      Nick Jonas  2wJhFcye5iiW2mVBpGednz             234213
# 18                The Chainsmokers  7BKLCZ1jbUBVqRi2FVlTVw             244960
# 19                  Dillon Francis  6m3ZWIXhjoV76syT1j2oE9             178333
# 20                     Post Malone  3a1lNhkSLSkpJE4MSHpDu9             220293
# 21                       Echosmith  13P5rwmk2EsoFRIz9UCeh9             237626
# 22                     OneRepublic  519uJbE3zyKLlToVA65PrP             257266
# 23                     Calum Scott  02WacdrRpm4zlP8H7X6bnQ             260004
# 24                 Imagine Dragons  2Oehrcv4Kov0SuIgWyQY9e             175200
# 25                  Arctic Monkeys  2UzMpPKPhbcC8RbsmuURAZ             272386
# 26                              MØ  4qqArAiTPueDxIp7cf87h7             235826
# 27                      The Script  49kjlZP49LMD1MrrcvXDET             252440
# 28                        Vigiland  7HGHhLbAklVxGkYdwyeVML             173871
# 29                       Vance Joy  6uEIbSu5Omm6Rg2hcVrfJH             230506
# ..                             ...                     ...                ...
# 639                    Chuck Berry  6OrnVjcEwJqEuoG50k4LQ0             142906
# 640                           Dion  1JOir33J9gtVyBN8VsmKqn             160306
# 641                    Del Shannon  0BY6W6PWdlghnZ41Uo5Eyz             139320
# 642                   LaVern Baker  0HsYttDxOv3neiw3L0wimY             149093
# 643        Bill Haley & His Comets  1s4hyUFWmLWiAamsclb4xA             165360
# 644        Bill Haley & His Comets  2JoXjemDQe0fSmk26CpfrP             150466
# 645      Johnny Kidd & The Pirates  2XDQ53SHZfUyX9zzAyUXmN             139733
# 646             The Isley Brothers  4J7VWj4ibCSw3tCiRKpypm             272560
# 647                  The Skyliners  5zgzOyEZPoeQwmXFzW0bPn             156893
# 648           Tennessee Ernie Ford  3P6OwCX7Ofiaaqtvujb6i5             158306
# 649                   The Platters  3z0Fm7pHB6ojjfj8JY6QRW             158546
# 650                 Connie Francis  4C0wRKBEUuYonk1uxXjxGG             136426
# 651                  Eddie Cochran  2wwRSaZgshcHSvGzWryUIi             120000
# 652                      Bobby Vee  1MR7XamWS0XH6vZxeeRdE0             150866
# 653                     Patti Page  7t8Tzd9FqVz2asFMCL0HpZ             183573
# 654                     The Champs  14bUqUj1EUnQabWeAqnj39             130320
# 655                    Buddy Holly  49dOnz1NuDgUNba91MudGy             136800
# 656                    Dean Martin  7ha6LU5Dle7FGBh0I9LZIa             188466
# 657                   The Platters  7DPxY0fRDRHeWRtLZZoOyt             159288
# 658                           Dion  4EoUALVwY4i7U6uKRhk8hr             163626
# 659                The Five Satins  5VyJGb6l6rY8bBZH2RC6XD             165866
# 660                 Little Richard  3Os0VNtvEnRFlXSK5dvOFu             146640
# 661                   The Drifters  5eh0402zJwaohvhArtKhQ4             157640
# 662            The Everly Brothers  7mVbL1b8HC1rW4Jle6ypG3             123000
# 663  Frankie Lymon & The Teenagers  6pqleSjOGb4XP9tjU7IwCv             179466
# 664                Jerry Lee Lewis  6wO13Xb3EdHUNixFOEJ0KV             172400
# 665  Frankie Lymon & The Teenagers  6vL5Kx5LmZzcL12DZl2OiY             138973
# 666                     Lee Dorsey  2pMwweGkjNLXZkSDZ63LYf             146053
# 667                      Sam Cooke  1uaHZMJyULGDBiNa9pk3FV             173026
# 668                Johnny Burnette  5HEDjLbZzujPv6xiylsCQ2             118333
#
#                  added_at  track.popularity  \
# 0    2018-12-01T17:58:03Z                68
# 1    2018-12-01T17:58:03Z                70
# 2    2018-12-01T17:58:03Z                72
# 3    2018-12-01T17:58:03Z                68
# 4    2018-12-01T17:58:03Z                72
# 5    2018-12-01T17:58:03Z                12
# 6    2018-12-01T17:58:03Z                15
# 7    2018-12-01T17:58:03Z                23
# 8    2018-12-01T17:58:03Z                15
# 9    2018-12-01T17:58:03Z                53
# 10   2018-12-01T17:58:03Z                68
# 11   2018-12-01T17:58:03Z                75
# 12   2018-12-01T17:58:03Z                16
# 13   2018-12-01T17:58:03Z                79
# 14   2018-12-01T17:58:03Z                77
# 15   2018-12-01T17:58:03Z                66
# 16   2018-12-01T17:58:03Z                73
# 17   2018-12-01T17:58:03Z                60
# 18   2018-12-01T17:58:03Z                84
# 19   2018-12-01T17:58:03Z                63
# 20   2018-12-01T17:58:03Z                84
# 21   2018-12-01T17:58:03Z                68
# 22   2018-12-01T17:58:03Z                16
# 23   2018-12-01T17:58:03Z                27
# 24   2018-12-01T17:58:03Z                28
# 25   2018-12-01T17:58:03Z                42
# 26   2018-12-01T17:58:03Z                70
# 27   2018-12-01T17:58:03Z                66
# 28   2018-12-01T17:58:03Z                21
# 29   2018-12-01T17:58:03Z                28
# ..                    ...               ...
# 639  2018-10-02T00:00:48Z                11
# 640  2018-10-02T00:00:48Z                13
# 641  2018-10-02T00:00:48Z                49
# 642  2018-10-02T00:00:48Z                48
# 643  2018-10-02T00:00:48Z                49
# 644  2018-10-02T00:00:48Z                57
# 645  2018-10-02T00:00:48Z                41
# 646  2018-10-02T00:00:48Z                48
# 647  2018-10-02T00:00:48Z                 8
# 648  2018-10-02T00:00:48Z                55
# 649  2018-10-02T00:00:48Z                42
# 650  2018-10-02T00:00:48Z                45
# 651  2018-10-02T00:00:48Z                14
# 652  2018-10-02T00:00:48Z                58
# 653  2018-10-02T00:00:48Z                 7
# 654  2018-10-02T00:00:48Z                54
# 655  2018-10-02T00:00:48Z                54
# 656  2018-10-02T00:00:48Z                59
# 657  2018-10-02T00:00:48Z                48
# 658  2018-10-02T00:00:48Z                63
# 659  2018-10-02T00:00:48Z                45
# 660  2018-10-02T00:00:48Z                10
# 661  2018-10-02T00:00:48Z                53
# 662  2018-10-02T00:00:48Z                45
# 663  2018-10-02T00:00:48Z                42
# 664  2018-10-02T00:00:48Z                58
# 665  2018-10-02T00:00:48Z                52
# 666  2018-10-02T00:00:48Z                48
# 667  2018-10-02T00:00:48Z                 8
# 668  2018-10-02T00:00:48Z                 7
#
#                                             track.name  acousticness  \
# 0                                A Head Full Of Dreams       0.00200
# 1                                         Ain't It Fun       0.15400
# 2                    Airplanes (feat. Hayley Williams)       0.11000
# 3                                           All I Want       0.17200
# 4    All My Friends (feat. Tinashe & Chance the Rap...       0.11900
# 5                                       Bad Intentions       0.22300
# 6                                              Believe       0.03430
# 7                                  Best Day Of My Life       0.06250
# 8                                       Blame It on Me       0.43500
# 9                                       Bloodsport '15       0.02300
# 10                                         Bloodstream       0.52900
# 11                                            Budapest       0.08830
# 12                                             Capsize       0.04200
# 13                                  Castle on the Hill       0.02320
# 14                                           Centuries       0.00400
# 15                                       Charlie Brown       0.02120
# 16                                             Classic       0.03840
# 17                                               Close       0.25300
# 18                                              Closer       0.41400
# 19                                         Coming Over       0.22700
# 20                                     Congratulations       0.21500
# 21                                           Cool Kids       0.03720
# 22                                      Counting Stars       0.06600
# 23                                   Dancing On My Own       0.85100
# 24                                              Demons       0.20200
# 25                                    Do I Wanna Know?       0.17400
# 26                                          Final Song       0.01400
# 27                                  For the First Time       0.03390
# 28                                        Friday Night       0.00104
# 29                                             Georgia       0.31200
# ..                                                 ...           ...
# 639               Roll Over Beethoven - Single Version       0.84900
# 640                    Runaround Sue - Remastered 1991       0.31200
# 641                  Runaway - 2004 Remastered Version       0.17200
# 642                                      See See Rider       0.64300
# 643                           See You Later, Alligator       0.31300
# 644            Shake, Rattle And Roll - Single Version       0.15900
# 645         Shakin' All Over - 2004 Remastered Version       0.17100
# 646                                              Shout       0.72500
# 647                             Since I Don't Have You       0.71700
# 648                                       Sixteen Tons       0.79600
# 649           Smoke Gets In Your Eyes - Single Version       0.93600
# 650                                       Stupid Cupid       0.66200
# 651                                   Summertime Blues       0.38700
# 652        Take Good Care Of My Baby - 1990 Remastered       0.69800
# 653                                    Tennessee Waltz       0.95700
# 654                                 Tequila (Original)       0.05190
# 655                                 That'll Be The Day       0.60800
# 656               That's Amore - 1996 Digital Remaster       0.66300
# 657               The Great Pretender - Single Version       0.87200
# 658                                       The Wanderer       0.82300
# 659                                       To The Aisle       0.91000
# 660                                       Tutti Frutti       0.78200
# 661                                Under the Boardwalk       0.66600
# 662     Wake Up Little Susie - 2006 Remastered Version       0.23800
# 663  Who Put The Bomp (In The Bomp Bomp Bomp) - 200...       0.60300
# 664                      Whole Lot of Shakin' Going On       0.83200
# 665                          Why Do Fools Fall in Love       0.61700
# 666                                              Ya Ya       0.60700
# 667                                        You Send Me       0.91500
# 668  You're Sixteen-Your're Beautiful (And You're M...       0.30400
#
#      danceability  duration_ms  energy                      id  \
# 0           0.450       223773   0.920  6f49kbOuQSOsStBpyGvQfA
# 1           0.610       296520   0.893  1j8z4TTjJ1YOdoFEDwJTQa
# 2           0.660       180480   0.867  6lV2MSQmRIkycDScNtrBXO
# 3           0.209       305747   0.412  2PwXOevGUSkU8qaYZjgLq2
# 4           0.689       229747   0.521  6TaqooOXAEcijL6G1AWS2K
# 5           0.744       245723   0.722  3rvLfPT9sm9UPeIr8OQA65
# 6           0.366       220867   0.685  7HqtFBLJcilvyUuMav4Y5W
# 7           0.670       194240   0.905  5j9iuo3tMmQIfnEEQOOjxh
# 8           0.526       196627   0.719  7vjjfdum71w8bbkNSQdnDL
# 9           0.591       259133   0.559  7EHv6Eb7nQOXhO0BW5gytT
# 10          0.660       300253   0.316  5v4sZRuvWDcisoOk1PFv6T
# 11          0.714       200720   0.451  7GJClzimvMSghjcrKxuf1M
# 12          0.681       237760   0.708  3GBlLqIYgB8zWaeWDNJzdh
# 13          0.461       261154   0.834  6PCUP3dWmTjcTtXY02oFdT
# 14          0.385       228360   0.866  04aAxqtGp5pv12UXAg4pkq
# 15          0.430       285160   0.738  1yqMgZNrevsWMLWfO2PRp5
# 16          0.720       175427   0.791  6FE2iI43OZnszFLuLtvvmg
# 17          0.653       234213   0.623  2wJhFcye5iiW2mVBpGednz
# 18          0.748       244960   0.524  7BKLCZ1jbUBVqRi2FVlTVw
# 19          0.631       178333   0.661  6m3ZWIXhjoV76syT1j2oE9
# 20          0.630       220293   0.804  3a1lNhkSLSkpJE4MSHpDu9
# 21          0.719       237627   0.671  13P5rwmk2EsoFRIz9UCeh9
# 22          0.665       257267   0.700  519uJbE3zyKLlToVA65PrP
# 23          0.608       260004   0.174  02WacdrRpm4zlP8H7X6bnQ
# 24          0.327       175200   0.710  2Oehrcv4Kov0SuIgWyQY9e
# 25          0.550       272387   0.532  2UzMpPKPhbcC8RbsmuURAZ
# 26          0.695       235827   0.672  4qqArAiTPueDxIp7cf87h7
# 27          0.393       252440   0.633  49kjlZP49LMD1MrrcvXDET
# 28          0.718       173871   0.673  7HGHhLbAklVxGkYdwyeVML
# 29          0.388       230507   0.660  6uEIbSu5Omm6Rg2hcVrfJH
# ..            ...          ...     ...                     ...
# 639         0.723       142907   0.931  6OrnVjcEwJqEuoG50k4LQ0
# 640         0.564       160307   0.493  1JOir33J9gtVyBN8VsmKqn
# 641         0.535       139320   0.579  0BY6W6PWdlghnZ41Uo5Eyz
# 642         0.674       149093   0.371  0HsYttDxOv3neiw3L0wimY
# 643         0.664       165360   0.702  1s4hyUFWmLWiAamsclb4xA
# 644         0.671       150467   0.679  2JoXjemDQe0fSmk26CpfrP
# 645         0.772       139733   0.672  2XDQ53SHZfUyX9zzAyUXmN
# 646         0.458       272560   0.890  4J7VWj4ibCSw3tCiRKpypm
# 647         0.212       156893   0.334  5zgzOyEZPoeQwmXFzW0bPn
# 648         0.693       158307   0.324  3P6OwCX7Ofiaaqtvujb6i5
# 649         0.357       158547   0.269  3z0Fm7pHB6ojjfj8JY6QRW
# 650         0.603       136427   0.755  4C0wRKBEUuYonk1uxXjxGG
# 651         0.721       120000   0.820  2wwRSaZgshcHSvGzWryUIi
# 652         0.491       150867   0.431  1MR7XamWS0XH6vZxeeRdE0
# 653         0.468       183573   0.171  7t8Tzd9FqVz2asFMCL0HpZ
# 654         0.532       130320   0.961  14bUqUj1EUnQabWeAqnj39
# 655         0.651       136800   0.528  49dOnz1NuDgUNba91MudGy
# 656         0.505       188467   0.155  7ha6LU5Dle7FGBh0I9LZIa
# 657         0.500       159289   0.377  7DPxY0fRDRHeWRtLZZoOyt
# 658         0.605       163627   0.544  4EoUALVwY4i7U6uKRhk8hr
# 659         0.323       165867   0.273  5VyJGb6l6rY8bBZH2RC6XD
# 660         0.532       146640   0.591  3Os0VNtvEnRFlXSK5dvOFu
# 661         0.726       157640   0.356  5eh0402zJwaohvhArtKhQ4
# 662         0.741       123000   0.666  7mVbL1b8HC1rW4Jle6ypG3
# 663         0.582       179467   0.517  6pqleSjOGb4XP9tjU7IwCv
# 664         0.377       172400   0.626  6wO13Xb3EdHUNixFOEJ0KV
# 665         0.439       138973   0.458  6vL5Kx5LmZzcL12DZl2OiY
# 666         0.758       146053   0.557  2pMwweGkjNLXZkSDZ63LYf
# 667         0.574       173027   0.250  1uaHZMJyULGDBiNa9pk3FV
# 668         0.419       118333   0.449  5HEDjLbZzujPv6xiylsCQ2
#
#      instrumentalness  key  liveness  loudness  speechiness    tempo  \
# 0            0.020100   11    0.3340    -4.982       0.0733  122.979
# 1            0.000044    9    0.0210    -3.681       0.0921  104.031
# 2            0.000000    6    0.0368    -4.285       0.1160   93.033
# 3            0.150000    0    0.0843    -9.733       0.0443   86.260
# 4            0.000084    0    0.1080    -5.845       0.1320   95.055
# 5            0.000000   11    0.0960    -5.140       0.0778  124.008
# 6            0.024800   11    0.2320    -5.910       0.0437  113.706
# 7            0.000151    2    0.0577    -2.385       0.0339  100.021
# 8            0.000000    3    0.3200    -4.472       0.0281  103.849
# 9            0.000000    6    0.0916    -6.319       0.0714   92.394
# 10           0.000294    3    0.1040   -11.567       0.0364   91.207
# 11           0.000000    5    0.1080    -8.268       0.0276  127.787
# 12           0.140000    5    0.6820    -6.019       0.0304   92.993
# 13           0.000011    2    0.1400    -4.868       0.0989  135.007
# 14           0.000000    4    0.1110    -2.817       0.0697  176.014
# 15           0.001650   10    0.3300    -7.076       0.0375  137.986
# 16           0.000000    1    0.1570    -4.689       0.1240  102.071
# 17           0.000000    6    0.1440    -5.273       0.0820  123.999
# 18           0.000000    8    0.1110    -5.599       0.0338   95.010
# 19           0.000001    5    0.1660    -5.500       0.0999  174.031
# 20           0.000000    6    0.2530    -4.183       0.0363  123.146
# 21           0.000008    8    0.1200    -6.279       0.0336  130.027
# 22           0.000000    1    0.1190    -4.946       0.0420  121.961
# 23           0.000019    1    0.0855    -8.796       0.0332  112.175
# 24           0.000090    3    0.2800    -2.928       0.0547  179.561
# 25           0.000347    5    0.2180    -7.591       0.0320   85.032
# 26           0.000084    1    0.0756    -6.109       0.0345  104.988
# 27           0.000000    9    0.1040    -4.769       0.0275  174.022
# 28           0.000012    1    0.0577    -5.567       0.0366  128.051
# 29           0.000307   11    0.0943    -7.372       0.0308  143.554
# ..                ...  ...       ...       ...          ...      ...
# 639          0.000000    3    0.2050    -5.528       0.1840   92.684
# 640          0.000000    2    0.4830   -12.349       0.0795   79.368
# 641          0.000000    8    0.0936    -6.156       0.0529   75.750
# 642          0.000000    1    0.0419   -16.429       0.0626   93.834
# 643          0.000002   10    0.3690   -11.841       0.0671  156.987
# 644          0.000000    5    0.1580   -11.237       0.1420  166.726
# 645          0.000012    9    0.3590    -6.653       0.0373  125.227
# 646          0.000000   10    0.8330    -5.736       0.0841  137.382
# 647          0.005600    6    0.0936   -12.196       0.0308  141.071
# 648          0.000000   11    0.2460   -15.085       0.2050  144.140
# 649          0.000090    3    0.4280    -9.981       0.0272   57.304
# 650          0.000019    3    0.0764    -6.396       0.0380  136.373
# 651          0.000326   11    0.1980   -10.320       0.0448  155.968
# 652          0.000000    1    0.1240   -12.257       0.0609   82.443
# 653          0.000037    5    0.1420   -10.905       0.0303   86.525
# 654          0.905000   10    0.0738    -4.056       0.0522   90.647
# 655          0.000000    9    0.3420    -8.033       0.0294  126.707
# 656          0.000000   10    0.1010   -12.959       0.0336   79.221
# 657          0.000000    7    0.3320    -5.895       0.0319  114.055
# 658          0.005790    2    0.3380   -11.370       0.0682  115.779
# 659          0.000000    5    0.1000   -10.152       0.0355  194.882
# 660          0.000000    0    0.0647    -3.810       0.0591  184.400
# 661          0.000000    7    0.1520   -10.091       0.0399  123.885
# 662          0.000000    2    0.3120    -6.878       0.0326   93.686
# 663          0.000000    5    0.3020    -9.325       0.0367   83.682
# 664          0.000065    0    0.1880    -9.662       0.0330  161.468
# 665          0.000060    1    0.1210    -9.906       0.0675  174.147
# 666          0.000218    5    0.1930   -10.106       0.0453  140.795
# 667          0.000000    4    0.1460   -10.307       0.0276   96.740
# 668          0.000003    2    0.0725    -9.946       0.0533   76.322
#
#      time_signature  valence decade
# 0                 4   0.0773  2010s
# 1                 4   0.6730  2010s
# 2                 4   0.3770  2010s
# 3                 3   0.1620  2010s
# 4                 4   0.1780  2010s
# 5                 4   0.3930  2010s
# 6                 4   0.3690  2010s
# 7                 4   0.5160  2010s
# 8                 4   0.4670  2010s
# 9                 4   0.3480  2010s
# 10                4   0.5430  2010s
# 11                4   0.4060  2010s
# 12                4   0.3560  2010s
# 13                4   0.4710  2010s
# 14                4   0.5510  2010s
# 15                4   0.0944  2010s
# 16                4   0.7560  2010s
# 17                4   0.4010  2010s
# 18                4   0.6610  2010s
# 19                4   0.6980  2010s
# 20                4   0.4920  2010s
# 21                4   0.7860  2010s
# 22                4   0.4730  2010s
# 23                4   0.1930  2010s
# 24                4   0.4160  2010s
# 25                4   0.4100  2010s
# 26                4   0.2450  2010s
# 27                4   0.3820  2010s
# 28                4   0.0825  2010s
# 29                4   0.4010  2010s
# ..              ...      ...    ...
# 639               4   0.8060  1950s
# 640               4   0.6530  1950s
# 641               4   0.7430  1950s
# 642               4   0.9410  1950s
# 643               4   0.7370  1950s
# 644               4   0.8200  1950s
# 645               4   0.6940  1950s
# 646               4   0.6090  1950s
# 647               4   0.6380  1950s
# 648               4   0.3820  1950s
# 649               4   0.2210  1950s
# 650               4   0.9670  1950s
# 651               4   0.9660  1950s
# 652               4   0.6610  1950s
# 653               3   0.3570  1950s
# 654               4   0.7530  1950s
# 655               4   0.8730  1950s
# 656               4   0.4630  1950s
# 657               3   0.6070  1950s
# 658               4   0.7970  1950s
# 659               3   0.5470  1950s
# 660               4   0.9620  1950s
# 661               4   0.7500  1950s
# 662               4   0.9410  1950s
# 663               4   0.8330  1950s
# 664               4   0.6780  1950s
# 665               4   0.8660  1950s
# 666               4   0.8870  1950s
# 667               4   0.4430  1950s
# 668               4   0.7560  1950s
#
# [669 rows x 20 columns]

# %%
decades_data['energy'].groupby(decades_data['decade']).mean().plot(kind='bar')
plt.ylabel('Energy')
plt.xlabel('Decade')
plt.title('Energy in Songs Over Decades')
plt.show()

decades_data['track.popularity'].groupby(decades_data['decade']).mean().plot(kind='bar')
plt.ylabel('Popoularity')
plt.xlabel('Decade')
plt.title('Popularity in Songs Over Decades')
plt.show()

decades_data['danceability'].groupby(decades_data['decade']).mean().plot(kind='bar')
plt.ylabel('Danceability')
plt.xlabel('Decade')
plt.title('Danceability in Songs Over Decades')
plt.show()

decades_data['liveness'].groupby(decades_data['decade']).mean().plot(kind='bar')
plt.ylabel('Liveness')
plt.xlabel('Decade')
plt.title('Liveness in Songs Over Decades')
plt.show()

decades_data['speechiness'].groupby(decades_data['decade']).mean().plot(kind='bar')
plt.ylabel('Speechiness')
plt.xlabel('Decade')
plt.title('Speechiness in Songs Over Decades')
plt.show()

decades_data['instrumentalness'].groupby(decades_data['decade']).mean().plot(kind='bar')
plt.ylabel('Instrumentalness')
plt.xlabel('Decade')
plt.title('Instrumentalness in Songs Over Decades')
plt.show()

# %%
decades_data
# Out:
#                               name                track.id  track.duration_ms  \
# 0                         Coldplay  6f49kbOuQSOsStBpyGvQfA             223773
# 1                         Paramore  1j8z4TTjJ1YOdoFEDwJTQa             296520
# 2                            B.o.B  6lV2MSQmRIkycDScNtrBXO             180480
# 3                         Kodaline  2PwXOevGUSkU8qaYZjgLq2             305746
# 4                        Snakehips  6TaqooOXAEcijL6G1AWS2K             229746
# 5                    Niykee Heaton  3rvLfPT9sm9UPeIr8OQA65             245722
# 6                   Mumford & Sons  7HqtFBLJcilvyUuMav4Y5W             220866
# 7                 American Authors  5j9iuo3tMmQIfnEEQOOjxh             194240
# 8                      George Ezra  7vjjfdum71w8bbkNSQdnDL             196626
# 9                  Raleigh Ritchie  7EHv6Eb7nQOXhO0BW5gytT             259133
# 10                      Ed Sheeran  5v4sZRuvWDcisoOk1PFv6T             300253
# 11                     George Ezra  7GJClzimvMSghjcrKxuf1M             200720
# 12                        FRENSHIP  3GBlLqIYgB8zWaeWDNJzdh             237760
# 13                      Ed Sheeran  6PCUP3dWmTjcTtXY02oFdT             261153
# 14                    Fall Out Boy  04aAxqtGp5pv12UXAg4pkq             228360
# 15                        Coldplay  1yqMgZNrevsWMLWfO2PRp5             285159
# 16                            MKTO  6FE2iI43OZnszFLuLtvvmg             175426
# 17                      Nick Jonas  2wJhFcye5iiW2mVBpGednz             234213
# 18                The Chainsmokers  7BKLCZ1jbUBVqRi2FVlTVw             244960
# 19                  Dillon Francis  6m3ZWIXhjoV76syT1j2oE9             178333
# 20                     Post Malone  3a1lNhkSLSkpJE4MSHpDu9             220293
# 21                       Echosmith  13P5rwmk2EsoFRIz9UCeh9             237626
# 22                     OneRepublic  519uJbE3zyKLlToVA65PrP             257266
# 23                     Calum Scott  02WacdrRpm4zlP8H7X6bnQ             260004
# 24                 Imagine Dragons  2Oehrcv4Kov0SuIgWyQY9e             175200
# 25                  Arctic Monkeys  2UzMpPKPhbcC8RbsmuURAZ             272386
# 26                              MØ  4qqArAiTPueDxIp7cf87h7             235826
# 27                      The Script  49kjlZP49LMD1MrrcvXDET             252440
# 28                        Vigiland  7HGHhLbAklVxGkYdwyeVML             173871
# 29                       Vance Joy  6uEIbSu5Omm6Rg2hcVrfJH             230506
# ..                             ...                     ...                ...
# 639                    Chuck Berry  6OrnVjcEwJqEuoG50k4LQ0             142906
# 640                           Dion  1JOir33J9gtVyBN8VsmKqn             160306
# 641                    Del Shannon  0BY6W6PWdlghnZ41Uo5Eyz             139320
# 642                   LaVern Baker  0HsYttDxOv3neiw3L0wimY             149093
# 643        Bill Haley & His Comets  1s4hyUFWmLWiAamsclb4xA             165360
# 644        Bill Haley & His Comets  2JoXjemDQe0fSmk26CpfrP             150466
# 645      Johnny Kidd & The Pirates  2XDQ53SHZfUyX9zzAyUXmN             139733
# 646             The Isley Brothers  4J7VWj4ibCSw3tCiRKpypm             272560
# 647                  The Skyliners  5zgzOyEZPoeQwmXFzW0bPn             156893
# 648           Tennessee Ernie Ford  3P6OwCX7Ofiaaqtvujb6i5             158306
# 649                   The Platters  3z0Fm7pHB6ojjfj8JY6QRW             158546
# 650                 Connie Francis  4C0wRKBEUuYonk1uxXjxGG             136426
# 651                  Eddie Cochran  2wwRSaZgshcHSvGzWryUIi             120000
# 652                      Bobby Vee  1MR7XamWS0XH6vZxeeRdE0             150866
# 653                     Patti Page  7t8Tzd9FqVz2asFMCL0HpZ             183573
# 654                     The Champs  14bUqUj1EUnQabWeAqnj39             130320
# 655                    Buddy Holly  49dOnz1NuDgUNba91MudGy             136800
# 656                    Dean Martin  7ha6LU5Dle7FGBh0I9LZIa             188466
# 657                   The Platters  7DPxY0fRDRHeWRtLZZoOyt             159288
# 658                           Dion  4EoUALVwY4i7U6uKRhk8hr             163626
# 659                The Five Satins  5VyJGb6l6rY8bBZH2RC6XD             165866
# 660                 Little Richard  3Os0VNtvEnRFlXSK5dvOFu             146640
# 661                   The Drifters  5eh0402zJwaohvhArtKhQ4             157640
# 662            The Everly Brothers  7mVbL1b8HC1rW4Jle6ypG3             123000
# 663  Frankie Lymon & The Teenagers  6pqleSjOGb4XP9tjU7IwCv             179466
# 664                Jerry Lee Lewis  6wO13Xb3EdHUNixFOEJ0KV             172400
# 665  Frankie Lymon & The Teenagers  6vL5Kx5LmZzcL12DZl2OiY             138973
# 666                     Lee Dorsey  2pMwweGkjNLXZkSDZ63LYf             146053
# 667                      Sam Cooke  1uaHZMJyULGDBiNa9pk3FV             173026
# 668                Johnny Burnette  5HEDjLbZzujPv6xiylsCQ2             118333
#
#                  added_at  track.popularity  \
# 0    2018-12-01T17:58:03Z                68
# 1    2018-12-01T17:58:03Z                70
# 2    2018-12-01T17:58:03Z                72
# 3    2018-12-01T17:58:03Z                68
# 4    2018-12-01T17:58:03Z                72
# 5    2018-12-01T17:58:03Z                12
# 6    2018-12-01T17:58:03Z                15
# 7    2018-12-01T17:58:03Z                23
# 8    2018-12-01T17:58:03Z                15
# 9    2018-12-01T17:58:03Z                53
# 10   2018-12-01T17:58:03Z                68
# 11   2018-12-01T17:58:03Z                75
# 12   2018-12-01T17:58:03Z                16
# 13   2018-12-01T17:58:03Z                79
# 14   2018-12-01T17:58:03Z                77
# 15   2018-12-01T17:58:03Z                66
# 16   2018-12-01T17:58:03Z                73
# 17   2018-12-01T17:58:03Z                60
# 18   2018-12-01T17:58:03Z                84
# 19   2018-12-01T17:58:03Z                63
# 20   2018-12-01T17:58:03Z                84
# 21   2018-12-01T17:58:03Z                68
# 22   2018-12-01T17:58:03Z                16
# 23   2018-12-01T17:58:03Z                27
# 24   2018-12-01T17:58:03Z                28
# 25   2018-12-01T17:58:03Z                42
# 26   2018-12-01T17:58:03Z                70
# 27   2018-12-01T17:58:03Z                66
# 28   2018-12-01T17:58:03Z                21
# 29   2018-12-01T17:58:03Z                28
# ..                    ...               ...
# 639  2018-10-02T00:00:48Z                11
# 640  2018-10-02T00:00:48Z                13
# 641  2018-10-02T00:00:48Z                49
# 642  2018-10-02T00:00:48Z                48
# 643  2018-10-02T00:00:48Z                49
# 644  2018-10-02T00:00:48Z                57
# 645  2018-10-02T00:00:48Z                41
# 646  2018-10-02T00:00:48Z                48
# 647  2018-10-02T00:00:48Z                 8
# 648  2018-10-02T00:00:48Z                55
# 649  2018-10-02T00:00:48Z                42
# 650  2018-10-02T00:00:48Z                45
# 651  2018-10-02T00:00:48Z                14
# 652  2018-10-02T00:00:48Z                58
# 653  2018-10-02T00:00:48Z                 7
# 654  2018-10-02T00:00:48Z                54
# 655  2018-10-02T00:00:48Z                54
# 656  2018-10-02T00:00:48Z                59
# 657  2018-10-02T00:00:48Z                48
# 658  2018-10-02T00:00:48Z                63
# 659  2018-10-02T00:00:48Z                45
# 660  2018-10-02T00:00:48Z                10
# 661  2018-10-02T00:00:48Z                53
# 662  2018-10-02T00:00:48Z                45
# 663  2018-10-02T00:00:48Z                42
# 664  2018-10-02T00:00:48Z                58
# 665  2018-10-02T00:00:48Z                52
# 666  2018-10-02T00:00:48Z                48
# 667  2018-10-02T00:00:48Z                 8
# 668  2018-10-02T00:00:48Z                 7
#
#                                             track.name  acousticness  \
# 0                                A Head Full Of Dreams       0.00200
# 1                                         Ain't It Fun       0.15400
# 2                    Airplanes (feat. Hayley Williams)       0.11000
# 3                                           All I Want       0.17200
# 4    All My Friends (feat. Tinashe & Chance the Rap...       0.11900
# 5                                       Bad Intentions       0.22300
# 6                                              Believe       0.03430
# 7                                  Best Day Of My Life       0.06250
# 8                                       Blame It on Me       0.43500
# 9                                       Bloodsport '15       0.02300
# 10                                         Bloodstream       0.52900
# 11                                            Budapest       0.08830
# 12                                             Capsize       0.04200
# 13                                  Castle on the Hill       0.02320
# 14                                           Centuries       0.00400
# 15                                       Charlie Brown       0.02120
# 16                                             Classic       0.03840
# 17                                               Close       0.25300
# 18                                              Closer       0.41400
# 19                                         Coming Over       0.22700
# 20                                     Congratulations       0.21500
# 21                                           Cool Kids       0.03720
# 22                                      Counting Stars       0.06600
# 23                                   Dancing On My Own       0.85100
# 24                                              Demons       0.20200
# 25                                    Do I Wanna Know?       0.17400
# 26                                          Final Song       0.01400
# 27                                  For the First Time       0.03390
# 28                                        Friday Night       0.00104
# 29                                             Georgia       0.31200
# ..                                                 ...           ...
# 639               Roll Over Beethoven - Single Version       0.84900
# 640                    Runaround Sue - Remastered 1991       0.31200
# 641                  Runaway - 2004 Remastered Version       0.17200
# 642                                      See See Rider       0.64300
# 643                           See You Later, Alligator       0.31300
# 644            Shake, Rattle And Roll - Single Version       0.15900
# 645         Shakin' All Over - 2004 Remastered Version       0.17100
# 646                                              Shout       0.72500
# 647                             Since I Don't Have You       0.71700
# 648                                       Sixteen Tons       0.79600
# 649           Smoke Gets In Your Eyes - Single Version       0.93600
# 650                                       Stupid Cupid       0.66200
# 651                                   Summertime Blues       0.38700
# 652        Take Good Care Of My Baby - 1990 Remastered       0.69800
# 653                                    Tennessee Waltz       0.95700
# 654                                 Tequila (Original)       0.05190
# 655                                 That'll Be The Day       0.60800
# 656               That's Amore - 1996 Digital Remaster       0.66300
# 657               The Great Pretender - Single Version       0.87200
# 658                                       The Wanderer       0.82300
# 659                                       To The Aisle       0.91000
# 660                                       Tutti Frutti       0.78200
# 661                                Under the Boardwalk       0.66600
# 662     Wake Up Little Susie - 2006 Remastered Version       0.23800
# 663  Who Put The Bomp (In The Bomp Bomp Bomp) - 200...       0.60300
# 664                      Whole Lot of Shakin' Going On       0.83200
# 665                          Why Do Fools Fall in Love       0.61700
# 666                                              Ya Ya       0.60700
# 667                                        You Send Me       0.91500
# 668  You're Sixteen-Your're Beautiful (And You're M...       0.30400
#
#      danceability  duration_ms  energy                      id  \
# 0           0.450       223773   0.920  6f49kbOuQSOsStBpyGvQfA
# 1           0.610       296520   0.893  1j8z4TTjJ1YOdoFEDwJTQa
# 2           0.660       180480   0.867  6lV2MSQmRIkycDScNtrBXO
# 3           0.209       305747   0.412  2PwXOevGUSkU8qaYZjgLq2
# 4           0.689       229747   0.521  6TaqooOXAEcijL6G1AWS2K
# 5           0.744       245723   0.722  3rvLfPT9sm9UPeIr8OQA65
# 6           0.366       220867   0.685  7HqtFBLJcilvyUuMav4Y5W
# 7           0.670       194240   0.905  5j9iuo3tMmQIfnEEQOOjxh
# 8           0.526       196627   0.719  7vjjfdum71w8bbkNSQdnDL
# 9           0.591       259133   0.559  7EHv6Eb7nQOXhO0BW5gytT
# 10          0.660       300253   0.316  5v4sZRuvWDcisoOk1PFv6T
# 11          0.714       200720   0.451  7GJClzimvMSghjcrKxuf1M
# 12          0.681       237760   0.708  3GBlLqIYgB8zWaeWDNJzdh
# 13          0.461       261154   0.834  6PCUP3dWmTjcTtXY02oFdT
# 14          0.385       228360   0.866  04aAxqtGp5pv12UXAg4pkq
# 15          0.430       285160   0.738  1yqMgZNrevsWMLWfO2PRp5
# 16          0.720       175427   0.791  6FE2iI43OZnszFLuLtvvmg
# 17          0.653       234213   0.623  2wJhFcye5iiW2mVBpGednz
# 18          0.748       244960   0.524  7BKLCZ1jbUBVqRi2FVlTVw
# 19          0.631       178333   0.661  6m3ZWIXhjoV76syT1j2oE9
# 20          0.630       220293   0.804  3a1lNhkSLSkpJE4MSHpDu9
# 21          0.719       237627   0.671  13P5rwmk2EsoFRIz9UCeh9
# 22          0.665       257267   0.700  519uJbE3zyKLlToVA65PrP
# 23          0.608       260004   0.174  02WacdrRpm4zlP8H7X6bnQ
# 24          0.327       175200   0.710  2Oehrcv4Kov0SuIgWyQY9e
# 25          0.550       272387   0.532  2UzMpPKPhbcC8RbsmuURAZ
# 26          0.695       235827   0.672  4qqArAiTPueDxIp7cf87h7
# 27          0.393       252440   0.633  49kjlZP49LMD1MrrcvXDET
# 28          0.718       173871   0.673  7HGHhLbAklVxGkYdwyeVML
# 29          0.388       230507   0.660  6uEIbSu5Omm6Rg2hcVrfJH
# ..            ...          ...     ...                     ...
# 639         0.723       142907   0.931  6OrnVjcEwJqEuoG50k4LQ0
# 640         0.564       160307   0.493  1JOir33J9gtVyBN8VsmKqn
# 641         0.535       139320   0.579  0BY6W6PWdlghnZ41Uo5Eyz
# 642         0.674       149093   0.371  0HsYttDxOv3neiw3L0wimY
# 643         0.664       165360   0.702  1s4hyUFWmLWiAamsclb4xA
# 644         0.671       150467   0.679  2JoXjemDQe0fSmk26CpfrP
# 645         0.772       139733   0.672  2XDQ53SHZfUyX9zzAyUXmN
# 646         0.458       272560   0.890  4J7VWj4ibCSw3tCiRKpypm
# 647         0.212       156893   0.334  5zgzOyEZPoeQwmXFzW0bPn
# 648         0.693       158307   0.324  3P6OwCX7Ofiaaqtvujb6i5
# 649         0.357       158547   0.269  3z0Fm7pHB6ojjfj8JY6QRW
# 650         0.603       136427   0.755  4C0wRKBEUuYonk1uxXjxGG
# 651         0.721       120000   0.820  2wwRSaZgshcHSvGzWryUIi
# 652         0.491       150867   0.431  1MR7XamWS0XH6vZxeeRdE0
# 653         0.468       183573   0.171  7t8Tzd9FqVz2asFMCL0HpZ
# 654         0.532       130320   0.961  14bUqUj1EUnQabWeAqnj39
# 655         0.651       136800   0.528  49dOnz1NuDgUNba91MudGy
# 656         0.505       188467   0.155  7ha6LU5Dle7FGBh0I9LZIa
# 657         0.500       159289   0.377  7DPxY0fRDRHeWRtLZZoOyt
# 658         0.605       163627   0.544  4EoUALVwY4i7U6uKRhk8hr
# 659         0.323       165867   0.273  5VyJGb6l6rY8bBZH2RC6XD
# 660         0.532       146640   0.591  3Os0VNtvEnRFlXSK5dvOFu
# 661         0.726       157640   0.356  5eh0402zJwaohvhArtKhQ4
# 662         0.741       123000   0.666  7mVbL1b8HC1rW4Jle6ypG3
# 663         0.582       179467   0.517  6pqleSjOGb4XP9tjU7IwCv
# 664         0.377       172400   0.626  6wO13Xb3EdHUNixFOEJ0KV
# 665         0.439       138973   0.458  6vL5Kx5LmZzcL12DZl2OiY
# 666         0.758       146053   0.557  2pMwweGkjNLXZkSDZ63LYf
# 667         0.574       173027   0.250  1uaHZMJyULGDBiNa9pk3FV
# 668         0.419       118333   0.449  5HEDjLbZzujPv6xiylsCQ2
#
#      instrumentalness  key  liveness  loudness  speechiness    tempo  \
# 0            0.020100   11    0.3340    -4.982       0.0733  122.979
# 1            0.000044    9    0.0210    -3.681       0.0921  104.031
# 2            0.000000    6    0.0368    -4.285       0.1160   93.033
# 3            0.150000    0    0.0843    -9.733       0.0443   86.260
# 4            0.000084    0    0.1080    -5.845       0.1320   95.055
# 5            0.000000   11    0.0960    -5.140       0.0778  124.008
# 6            0.024800   11    0.2320    -5.910       0.0437  113.706
# 7            0.000151    2    0.0577    -2.385       0.0339  100.021
# 8            0.000000    3    0.3200    -4.472       0.0281  103.849
# 9            0.000000    6    0.0916    -6.319       0.0714   92.394
# 10           0.000294    3    0.1040   -11.567       0.0364   91.207
# 11           0.000000    5    0.1080    -8.268       0.0276  127.787
# 12           0.140000    5    0.6820    -6.019       0.0304   92.993
# 13           0.000011    2    0.1400    -4.868       0.0989  135.007
# 14           0.000000    4    0.1110    -2.817       0.0697  176.014
# 15           0.001650   10    0.3300    -7.076       0.0375  137.986
# 16           0.000000    1    0.1570    -4.689       0.1240  102.071
# 17           0.000000    6    0.1440    -5.273       0.0820  123.999
# 18           0.000000    8    0.1110    -5.599       0.0338   95.010
# 19           0.000001    5    0.1660    -5.500       0.0999  174.031
# 20           0.000000    6    0.2530    -4.183       0.0363  123.146
# 21           0.000008    8    0.1200    -6.279       0.0336  130.027
# 22           0.000000    1    0.1190    -4.946       0.0420  121.961
# 23           0.000019    1    0.0855    -8.796       0.0332  112.175
# 24           0.000090    3    0.2800    -2.928       0.0547  179.561
# 25           0.000347    5    0.2180    -7.591       0.0320   85.032
# 26           0.000084    1    0.0756    -6.109       0.0345  104.988
# 27           0.000000    9    0.1040    -4.769       0.0275  174.022
# 28           0.000012    1    0.0577    -5.567       0.0366  128.051
# 29           0.000307   11    0.0943    -7.372       0.0308  143.554
# ..                ...  ...       ...       ...          ...      ...
# 639          0.000000    3    0.2050    -5.528       0.1840   92.684
# 640          0.000000    2    0.4830   -12.349       0.0795   79.368
# 641          0.000000    8    0.0936    -6.156       0.0529   75.750
# 642          0.000000    1    0.0419   -16.429       0.0626   93.834
# 643          0.000002   10    0.3690   -11.841       0.0671  156.987
# 644          0.000000    5    0.1580   -11.237       0.1420  166.726
# 645          0.000012    9    0.3590    -6.653       0.0373  125.227
# 646          0.000000   10    0.8330    -5.736       0.0841  137.382
# 647          0.005600    6    0.0936   -12.196       0.0308  141.071
# 648          0.000000   11    0.2460   -15.085       0.2050  144.140
# 649          0.000090    3    0.4280    -9.981       0.0272   57.304
# 650          0.000019    3    0.0764    -6.396       0.0380  136.373
# 651          0.000326   11    0.1980   -10.320       0.0448  155.968
# 652          0.000000    1    0.1240   -12.257       0.0609   82.443
# 653          0.000037    5    0.1420   -10.905       0.0303   86.525
# 654          0.905000   10    0.0738    -4.056       0.0522   90.647
# 655          0.000000    9    0.3420    -8.033       0.0294  126.707
# 656          0.000000   10    0.1010   -12.959       0.0336   79.221
# 657          0.000000    7    0.3320    -5.895       0.0319  114.055
# 658          0.005790    2    0.3380   -11.370       0.0682  115.779
# 659          0.000000    5    0.1000   -10.152       0.0355  194.882
# 660          0.000000    0    0.0647    -3.810       0.0591  184.400
# 661          0.000000    7    0.1520   -10.091       0.0399  123.885
# 662          0.000000    2    0.3120    -6.878       0.0326   93.686
# 663          0.000000    5    0.3020    -9.325       0.0367   83.682
# 664          0.000065    0    0.1880    -9.662       0.0330  161.468
# 665          0.000060    1    0.1210    -9.906       0.0675  174.147
# 666          0.000218    5    0.1930   -10.106       0.0453  140.795
# 667          0.000000    4    0.1460   -10.307       0.0276   96.740
# 668          0.000003    2    0.0725    -9.946       0.0533   76.322
#
#      time_signature  valence decade
# 0                 4   0.0773  2010s
# 1                 4   0.6730  2010s
# 2                 4   0.3770  2010s
# 3                 3   0.1620  2010s
# 4                 4   0.1780  2010s
# 5                 4   0.3930  2010s
# 6                 4   0.3690  2010s
# 7                 4   0.5160  2010s
# 8                 4   0.4670  2010s
# 9                 4   0.3480  2010s
# 10                4   0.5430  2010s
# 11                4   0.4060  2010s
# 12                4   0.3560  2010s
# 13                4   0.4710  2010s
# 14                4   0.5510  2010s
# 15                4   0.0944  2010s
# 16                4   0.7560  2010s
# 17                4   0.4010  2010s
# 18                4   0.6610  2010s
# 19                4   0.6980  2010s
# 20                4   0.4920  2010s
# 21                4   0.7860  2010s
# 22                4   0.4730  2010s
# 23                4   0.1930  2010s
# 24                4   0.4160  2010s
# 25                4   0.4100  2010s
# 26                4   0.2450  2010s
# 27                4   0.3820  2010s
# 28                4   0.0825  2010s
# 29                4   0.4010  2010s
# ..              ...      ...    ...
# 639               4   0.8060  1950s
# 640               4   0.6530  1950s
# 641               4   0.7430  1950s
# 642               4   0.9410  1950s
# 643               4   0.7370  1950s
# 644               4   0.8200  1950s
# 645               4   0.6940  1950s
# 646               4   0.6090  1950s
# 647               4   0.6380  1950s
# 648               4   0.3820  1950s
# 649               4   0.2210  1950s
# 650               4   0.9670  1950s
# 651               4   0.9660  1950s
# 652               4   0.6610  1950s
# 653               3   0.3570  1950s
# 654               4   0.7530  1950s
# 655               4   0.8730  1950s
# 656               4   0.4630  1950s
# 657               3   0.6070  1950s
# 658               4   0.7970  1950s
# 659               3   0.5470  1950s
# 660               4   0.9620  1950s
# 661               4   0.7500  1950s
# 662               4   0.9410  1950s
# 663               4   0.8330  1950s
# 664               4   0.6780  1950s
# 665               4   0.8660  1950s
# 666               4   0.8870  1950s
# 667               4   0.4430  1950s
# 668               4   0.7560  1950s
#
# [669 rows x 20 columns]

# %% [markdown]
# ## Visualizing Song Lyrics through Genius and NLTK
# We thought it would be interesting to compare across decades and see if there is a difference in the prevalence of certain words. To do so, we used the Genius API to be able to get the lyrics of every song in our decades_data dataframe.

# %%
'''
    This method requests the URL of a song by querying by the song title and artist name
    Params: song_title -> string and artist_name -> string
    Returns: a string (either a song URL or an empty string if the song couldn't be found)
'''
def request_song_info(song_title, artist_name):
    # forming request
    base_url = 'https://api.genius.com'
    headers = {'Authorization': 'Bearer ' + genius_token}
    search_url = base_url + '/search'
    data = {'q': song_title.lower() + ' ' + artist_name.lower()}
    response = requests.get(search_url, data=data, headers=headers) # making the get request
    json = response.json()
    remote_song_info = None
    
    #Search resultls
    for hit in json['response']['hits']: #using the artist name to make sure we're actually getting the song we want
        if artist_name.lower() in hit['result']['primary_artist']['name'].lower():
            remote_song_info = hit
            break
        
    if remote_song_info: # returning song URL if matched
        song_url = remote_song_info['result']['url']
        return song_url
    else:
        return ""

# %% [markdown]
# #### Using NLTK
# It's not enough just to be able to get the lyrics of a song. If we want to get meaningful data, we will have to strip words like "the", "an", and "it". These are known as "stop words", and luckily, NTLK has a corpus of them. We can use NLTK to add a few stop-words that it doesn't pick up (like chorus, verse, nt, prechorus, and bridge). We can then filter these stop-words from the lyrics.

# %%
'''
    This method will return an array of the words within a song.
    Params: url -> string
    Returns: An array of words within the song
'''
def get_cleaned_lyrics(url):
    page = requests.get(url)
    html = BeautifulSoup(page.text, 'html.parser')
    lyrics = html.find('div', class_='lyrics').get_text()
    tokens = word_tokenize(lyrics) #Split the lyrics into an array of strings 
    # Some data-cleaning 
    tokens = [w.lower() for w in tokens] # convert them all to lowercase
    table = str.maketrans('', '', string.punctuation) # remove punctuation from each word
    stripped = [w.translate(table) for w in tokens]
    words = [word for word in stripped if word.isalpha()]     # remove remaining tokens that are not alphabetic

    # filter out stop words
    stop_words = set(stopwords.words('english'))
    stop_words.add("chorus")
    stop_words.add("verse")
    stop_words.add("nt")
    stop_words.add("prechorus")
    stop_words.add("bridge")

    words = [w for w in words if not w in stop_words] #filter out the stop-words
    return stop_words, words

# %% [markdown]
# ### Displaying The Results
# Now that we have the lyrics, we can create meaningful (and pretty!) visualizations to compare the frequency of words across decades. We will use the Seaborn and Wordcloud modules to be able to do this!

# %%
'''
    Generates a Word Cloud based on the frequency of words
    Param: freq -> Frequency object
    Return: Wordcloud object
'''
def generate_frequency_wordcloud(freq):
    wc = WordCloud()
    wc.generate_from_frequencies(freq)
    return wc

'''
    Displays a wordcloud 
    Param: wordcloud -> Wordcloud object, decade -> string
    Returns: Nothing, but displays a Wordcloud with the Decade string as the title
'''
def display_wordcloud(wordcloud, decade):
    plt.title(decade)
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.show()

'''
    Displays the frequency of a given dictionary of words in a bar-chart
    Params: freq -> dictionary, title -> string
    Returns: Nothing, but displays a bar chat with the given string as the title
'''
def display_barchart(freq, title):
    plt.title(title)
    sns.barplot(x=freq.keys(), y=freq.values())

# %%
'''
    Given an array of song titles and corresponding artist names, will return an array containing all of the lyrics
    for those songs
    Params: songs_arr -> list of strings, artist_arr -> list of strings
    Return: 
'''
def decades_song(songs_arr, artist_arr):
    lyr = []
    for song, artist in zip(songs_arr, artist_arr):
        url = request_song_info(song, artist)
        #print("URL: "+url)
        if url is not "": 
            stop_words, lyrics = get_cleaned_lyrics(url)
            lyr += lyrics
           
    return stop_words, lyr

# %%
# decades_group = decades_data.groupby("decade")
# decade_lyrics = {}
# frequencies = {}
# for name, group in decades_group:
#     print("==========")
#     #print(group["name"])
#     stop_words, lyr = decades_song(group["track.name"], group["name"])
#     frequencies[name] = lyr
#     decade_lyrics[name] = " ".join(lyr)
#     # want to aggregate all of the lyrics for a decade

# %%
# for key, value in decade_lyrics.items():
#     print("NORMAL: "+key)
#     display_wordcloud(generate_wordcloud(value), key)

# %%
# for key, value in frequencies.items():
#     print("FREQ: "+key)
#     fdist1 = nltk.FreqDist(value)
#     display_wordcloud(generate_frequency_wordcloud(fdist1), key)

# %%
# Let's cut down the data to the features I think are relevant
ml_data = decades_data 
ml_data = ml_data.drop(columns = ["name", "added_at", "track.name", "track.id"])
cols = ml_data.columns.tolist()
cols = cols[6:7] + cols[:6] + cols[8:]
ml_data = ml_data[cols]
#pd.concat([ml_data, y_encoded], axis = 1)

# %%
# Make classifier 
# might be good to have a normalized look at the data 
from sklearn.model_selection import cross_val_score

# can do linear classifier and decision tree and basic neural net : https://machinelearningmastery.com/multi-class-classification-tutorial-keras-deep-learning-library/
y_encoded = pd.get_dummies(ml_data["decade"])
features = ml_data.iloc[:, 1:-1]
features

#Let's do a Random Forest
X_train, X_test, y_train, y_test = train_test_split(features, y_encoded, test_size = 0.25, random_state = 21)

# scaling features
# Feature Scaling
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Fitting Random Forest Classification to the Training set
classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 42)
classifier.fit(X_train, y_train)

scores = cross_val_score(classifier, X_train, y_train, cv=10, scoring='accuracy')
print(scores.mean())

# Predicting the Test set results
y_pred = classifier.predict(X_test)
print(classifier.score(X_test, y_test))

import matplotlib.pyplot as plt

def plot_corr(df,size=10):
    corr = df.corr()
    fig, ax = plt.subplots(figsize=(size, size))
    ax.matshow(corr)
    plt.xticks(range(len(corr.columns)), corr.columns);
    plt.yticks(range(len(corr.columns)), corr.columns);

plot_corr(ml_data, size = 10)
corr_data = pd.concat([ml_data, y_encoded], axis = 1)

import seaborn as sns
corr = corr_data.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
# Out:
# 0.0898431372549
# 0.136904761905

# %%
# Scatter plots for KNN, maybe? 
#ml_data

# %%
from sklearn.neighbors import KNeighborsClassifier
# importing necessary libraries 
from sklearn import datasets 
from sklearn.metrics import confusion_matrix 
from sklearn.model_selection import train_test_split 
from sklearn.model_selection import cross_val_score

# https://kevinzakka.github.io/2016/07/13/k-nearest-neighbor/ 

# Train the model using the training sets
from sklearn import preprocessing
from sklearn import metrics

# training a KNN classifier 
from sklearn.neighbors import KNeighborsClassifier 
knn = KNeighborsClassifier(n_neighbors = 7).fit(X_train, y_train) 
  
# accuracy on X_test 
accuracy = knn.score(X_test, y_test) 
print (accuracy) 
#print(y_test)
# creating a confusion matrix 
knn_predictions = knn.predict(X_test)

classes = ["1950s", "1960s", "1970s", "1980s", "1990s", "2000s", "2010s"]


cm = confusion_matrix(y_test.values.argmax(axis=1), knn_predictions.argmax(axis=1)) 
#cm

# creating odd list of K for KNN
myList = list(range(1,50))

# subsetting just the odd ones
neighbors = filter(lambda x: x % 2 != 0, myList)

# empty list that will hold cv scores
cv_scores = []

# perform 10-fold cross validation
for k in neighbors:
    knn = KNeighborsClassifier(n_neighbors=k)
    scores = cross_val_score(knn, X_train, y_train, cv=10, scoring='accuracy')
    cv_scores.append(scores.mean())

# changing to misclassification error
MSE = [1 - x for x in cv_scores]
neighbors = list(filter(lambda x: x % 2 != 0, myList))

# determining best k
optimal_k = neighbors[MSE.index(min(MSE))]
print ("The optimal number of neighbors is %d" % optimal_k)

# plot misclassification error vs k
plt.plot(neighbors, MSE)
plt.xlabel('Number of Neighbors K')
plt.ylabel('Misclassification Error')
plt.show()

#plt.figure(figsize = (10,7))

decades_data.groupby("decade").agg(["count"])

knn = KNeighborsClassifier(n_neighbors = 1).fit(X_train, y_train) 
knn_predictions = knn.predict(X_test)

classes = ["1950s", "1960s", "1970s", "1980s", "1990s", "2000s", "2010s"]


cm = confusion_matrix(y_test.values.argmax(axis=1), knn_predictions.argmax(axis=1)) 

sns.set(font_scale=1.4)#for label size
heatmap = sns.heatmap(cm, annot=True,annot_kws={"size": 16})# font size
fontsize = 16
heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
heatmap.set(xticklabels=classes, yticklabels=classes)
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# 0.107142857143
# The optimal number of neighbors is 1
# Text(0.5,7.5,'Predicted label')

# %%
#plt.figure(figsize = (10,7))
sns.set(font_scale=1.4)#for label size
heatmap = sns.heatmap(cm, annot=True,annot_kws={"size": 16})# font size
fontsize = 16
heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
heatmap.set(xticklabels=classes, yticklabels=classes)
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5,7.5,'Predicted label')

# %%
def print_confusion_matrix(confusion_matrix, class_names, figsize = (10,7), fontsize=14):
    
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names, columns=class_names, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    return fig
